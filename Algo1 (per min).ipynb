# %% [markdown]
# # Link to transcript

# %%
from youtube_transcript_api import YouTubeTranscriptApi
import pandas as pd


def get_youtube_video_transcript_dataframe(youtube_url):
    try:
        # Extract video ID from the URL
        video_id = youtube_url.split("v=")[-1]

        # Get the transcript
        transcript = YouTubeTranscriptApi.get_transcript(video_id)

        # Create an empty list to store the transcript data
        transcript_data = []

        # Loop through each transcript item and extract timestamp and text
        for item in transcript:
            start_time = item["start"]
            end_time = item["start"] + item["duration"]
            text = item["text"]
            transcript_data.append({"Start": start_time, "End": end_time, "Text": text})

        # Convert the list to a pandas DataFrame
        df = pd.DataFrame(transcript_data)

        return df

    except Exception as e:
        print("Error:", e)
        return None

# Replace the following with the YouTube video URL of your choice
youtube_url = "https://www.youtube.com/watch?v=VyFk2sdw230&ab_channel=BiggerPockets"
transcript_df = get_youtube_video_transcript_dataframe(youtube_url)

if transcript_df is not None:
    print(transcript_df.head())
else:
    print("Failed to get the transcript.")
# Out:
#    Start     End                                      Text
# 0  0.000   5.339  welcome to mortgage Mondays Today's Show
# 1  2.280   6.720    we are going to break down an FHA loan
# 2  5.339   8.280     pretty much everything that you could
# 3  6.720   9.720      possibly need to know but if you now
# 4  8.280  10.980   show up to an appointment with the loan

# %% [markdown]
# # Preprocessed transcritpt

# %%
transcript_df
# Out:
#        Start      End                                      Text
# 0      0.000    5.339  welcome to mortgage Mondays Today's Show
# 1      2.280    6.720    we are going to break down an FHA loan
# 2      5.339    8.280     pretty much everything that you could
# 3      6.720    9.720      possibly need to know but if you now
# 4      8.280   10.980   show up to an appointment with the loan
# ..       ...      ...                                       ...
# 512  920.160  924.160  Pockets video thanks a lot love you guys
# 513  922.260  933.559                      go build some wealth
# 514  924.160  933.559                                   [Music]
# 515  937.390  944.480                                   [Music]
# 516  941.420  944.480                                 thank you
#
# [517 rows x 3 columns]

# %%
import pandas as pd

def group_rows_with_overlap(dataframe, window_size, overlap):
    combined_rows = []
    num_rows = len(dataframe)

    # Iterate over the rows with the specified overlap
    for i in range(0, num_rows, overlap):
        # Get the current window of rows
        window_rows = dataframe.iloc[i:i+window_size]

        if len(window_rows) > 0:
            # Get the 'text' column values and combine them
            combined_text = ' '.join(window_rows['Text'])

            # Get the first 'Start' value
            start_value = window_rows['Start'].iloc[0]

            # Create a new row with the combined 'text' and first 'start' value
            new_row = {
                'Start': start_value,
                'Text': combined_text
            }

            # Append the new row to the combined_rows list
            combined_rows.append(new_row)

    # Create a new DataFrame from the combined_rows list
    combined_df = pd.DataFrame(combined_rows)

    return combined_df

# Example usage
# Assuming you have a DataFrame called 'your_dataframe'
# and you want to take a sequence of 30 rows with an overlap of 10 rows
window_size = 30
overlap = 10

new_dataset_overlap = group_rows_with_overlap(transcript_df, window_size, overlap)
new_dataset_overlap.head()

# %%
new_dataset_overlap.head()
# Out:
#     Start                                               Text
# 0   0.000  welcome to mortgage Mondays Today's Show we ar...
# 1  16.260  person so prepare to be educated on FHA Loans ...
# 2  33.899  mortgage you can clear your debt build wealth ...
# 3  54.059  like BiggerPockets welcome to mortgage Mondays...
# 4  75.600  wanted to hear and you listen and many of you ...

# %% [markdown]
# ## The short trasncript data for algotihm

# %%
selected_word = pd.read_csv('slected_word.csv')
selected_word.head()
# Out:
#    Unnamed: 0        Word  Frequency
# 0           0      people         37
# 1           2    property         34
# 2           4      market         23
# 3           5         one         22
# 4           6  properties         20

# %% [markdown]
# # Algo select clip

# %%
import pandas as pd
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords

df = new_dataset_overlap

# Load NLTK stopwords
stop_words = set(stopwords.words("english"))

# Create the engaging words DataFrame
engaging_words_df = selected_word

# Function to preprocess the text and tokenize it
def preprocess_text(text):
    words = word_tokenize(text.lower())
    words = [word for word in words if word.isalnum() and word not in stop_words]
    return words

# Preprocess the text in the DataFrame
df["ProcessedText"] = df["Text"].apply(preprocess_text)

# Calculate word frequency across the entire transcript with weights for engaging words
word_frequency = {}
for _, row in df.iterrows():
    for word in row["ProcessedText"]:
        weight = engaging_words_df[engaging_words_df["Word"] == word]["Frequency"].values
        weight = weight[0] if len(weight) > 0 else 1  # Use 1 if word not found in engaging words DataFrame
        word_frequency[word] = word_frequency.get(word, 0) + weight

# Function to get the frequency score for a sentence
def get_sentence_frequency_score(sentence):
    words = preprocess_text(sentence)
    score = sum(word_frequency.get(word, 0) for word in words)
    return score

# Rank sentences based on frequency score
df["FrequencyScore"] = df["Text"].apply(get_sentence_frequency_score)

# Set the number of sentences you want in the summary
num_sentences = 10

# Extract the top sentences to form the summary
summary_sentences = df.nlargest(num_sentences, "FrequencyScore")["Text"].values

# %%
summary_sentences
# Out:
# array(["FHA loan so in most cases when someone comes to us with the one brokerage and says I want to buy a primary residence I want a house act what can I do we start with the FHA low if you don't already have one that's usually what we do and if you do have one then we say well here's a conventional option or do you want to refinance out of the FHA and use that to buy so Christian what advice do you have for people that are going to approach their loan officer with this Vegas is that if you're not hearing this advice probably talking to the wrong guy you need to talk to somebody who's knowledgeable bread products don't talk to a loan officer that just offers one product it's the biggest mistake people make I go to Chase and I get a Chase loan okay that's not shade at Chase that's just a single bank that offers a single luck right go somewhere that knows different products that can help you pick the one that's right for you and can help you get in the property where you otherwise wouldn't be able to otherwise right Christian thank you so much for your time and sharing your knowledge regarding FHA Loans I feel smarter I'm sure a lot of our audience",
#        "are best for you okay tell me more about FHA Loans now a couple things that I'd like to note a lot of people say go buy a home every year FHA loan FHA loan rinse and repeat right that's not impossible but there's some obstacles to overcome number one you can only have one FHA loan at a time so these are going to be kind of some myths around the FHA one you can only have one at a time that does not mean you can only have one ever okay so you can buy refinance it out into another loan product and then buy again with an FHA FHA loaned is also not stay I just said what FHA stands for it does not stand for first home it is not a first time home buyers you could use it for your third fourth fifth Property okay FHA loan is does not have to be your first purchase and especially when you get into buying repeatedly using the FHA loan you can run into some trouble and there's two main things to look out when you move out of a residence and into another one and when you're using the FHA loan to qualify for that house you're moving into there's some rules and number one is that typically with loans when you move out you're turning",
#        "just gonna buy one house a year and I'm gonna buy up my whole block and that gets very difficult to qualify for when you can't use the rental income from the houses you're vacating every year number two probably the the most misunderstood Rule and then the least well-known one is the self-sufficiency rule this really hit us in California when you're buying a three and four unit property that's it this doesn't account for a single family or duplex but when you're buying a three and four unit the rent events of the whole property together so let's say you're buying a fourplex all four units even though you're occupying one of them let's say two thousand dollars a unit times four that's eight grand that money per month after a 75 haircut so they would take 25 off and only credit you with 75 has to be more than your mortgage and the problem in California is 75 of 8 000 is whatever six grand to buy a four Plex you're spending one and a half two million dollars your payments are pretty much always gonna be over six grand so in high cost of living areas that made three and four unit FHA purchases almost impossible right people would have to convert over to the",
#        "your old house into a rent this is getting into the weeds a little bit but I think it's important people understand this you're turning your old home into a rental that means we can credit you with some of the rental income to help qualify you for the loan FHA has a really weird role that unless you move more than a hundred miles away from that house you can't use rentaling so while that doesn't make the move impossible you have to make enough money to qualify for both mortgages at the same time if you don't move 100 miles away which most people aren't unless they get redeployed for work or you know repositioned or something or maybe they're moving family or going off to school or something so that's a big one that people a lot of times Overlook because they think I'm just gonna buy one house a year and I'm gonna buy up my whole block and that gets very difficult to qualify for when you can't use the rental income from the houses you're vacating every year number two probably the the most misunderstood Rule and then the least well-known one is the self-sufficiency rule this really hit us in California when you're buying a three and four unit property that's it",
#        "three or a four unit property assuming it meets the self-sufficiency rule which we talked about that's different than conventional loads right when you're buying a three or four unit property with a conventional loan what's the minimum down payment three or fours are going to be 22 unit is going to be 15. there we go and fhas you could still use three and a half percent down to buy these properties correct that's the massive advantage of FHA Loans not only will we talk about the credit not only will we talk about the debt's income utilization but the fact that the down payment doesn't change with unit account technically VA doesn't either but it's very different than any other product because it doesn't change the more house you buy right two three four units are all the same so what are the issues people are having right now is what I refer to as the golden handcuffs dilemma you bought a property with an FHA loan you have a killer interest rate 3.25 3.75 rates are going to be for uh primary residence probably closer to seven maybe High sixes right now you don't want to refi out of your FHA loan because you're going to get a worse rate",
#        "insurance at 75 of rents would that be the same as saying it has to be to 1.25 dscr ratio math doesn't work out exactly probably that way but it's very similar yeah after a 75 haircut it has to be one yeah why that rule is there I'm not sure it was probably honestly Fanning man Freddie Mac trying to limit people using FHA Loans every single year to buy a fourplex which is what we've been telling people to do for the whole time we've been on the bus yeah that's that's kind of the anti-bigger pockets rule right but you know it's a frustrating one but you can still rock it with you know single families and adus and duplexes three and four units have just become increasingly difficult to do with an FHA you know Christian you mentioned that an FHA loan can be used to buy a three or a four unit property assuming it meets the self-sufficiency rule which we talked about that's different than conventional loads right when you're buying a three or four unit property with a conventional loan what's the minimum down payment three or fours are going to be 22 unit is going to be 15. there we go and fhas you could still use three and a half percent down to buy"],
#       dtype=object)

# %% [markdown]
# # Clip with timestamp

# %% [markdown]
# # (optional) shows the video with cutted part
