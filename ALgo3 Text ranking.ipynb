# %%
from youtube_transcript_api import YouTubeTranscriptApi
import pandas as pd


def get_youtube_video_transcript_dataframe(youtube_url):
    try:
        # Extract video ID from the URL
        video_id = youtube_url.split("v=")[-1]

        # Get the transcript
        transcript = YouTubeTranscriptApi.get_transcript(video_id)

        # Create an empty list to store the transcript data
        transcript_data = []

        # Loop through each transcript item and extract timestamp and text
        for item in transcript:
            start_time = item["start"]
            end_time = item["start"] + item["duration"]
            text = item["text"]
            transcript_data.append({"Start": start_time, "End": end_time, "Text": text})

        # Convert the list to a pandas DataFrame
        df = pd.DataFrame(transcript_data)

        return df

    except Exception as e:
        print("Error:", e)
        return None

# Replace the following with the YouTube video URL of your choice
youtube_url = "https://www.youtube.com/watch?v=VyFk2sdw230&ab_channel=BiggerPockets"
transcript_df = get_youtube_video_transcript_dataframe(youtube_url)

if transcript_df is not None:
    print(transcript_df.head())
else:
    print("Failed to get the transcript.")
# Out:
#    Start     End                                      Text
# 0  0.000   5.339  welcome to mortgage Mondays Today's Show
# 1  2.280   6.720    we are going to break down an FHA loan
# 2  5.339   8.280     pretty much everything that you could
# 3  6.720   9.720      possibly need to know but if you now
# 4  8.280  10.980   show up to an appointment with the loan

# %% [markdown]
# # SUb topic segementation

# %%
import pandas as pd
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from gensim import corpora, models

def preprocess_text(text):
    tokens = word_tokenize(text)
    tokens = [word.lower() for word in tokens if word.isalpha()]
    
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(word) for word in tokens]
    
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]
    
    return tokens

# Example DataFrame
df = transcript_df

def cluster_dialogue(dataframe, num_topics=3):
    texts = [preprocess_text(text) for text in dataframe['Text']]
    dictionary = corpora.Dictionary(texts)
    corpus = [dictionary.doc2bow(text) for text in texts]
    
    lda_model = models.LdaModel(corpus, num_topics=num_topics, id2word=dictionary)
    
    topic_assignments = [max(lda_model[text], key=lambda item: item[1])[0] for text in corpus]
    dataframe['Subtopic'] = topic_assignments
    
    return dataframe

df_with_subtopics = cluster_dialogue(df, num_topics=2)

# Group messages by subtopic
subtopic_groups = df_with_subtopics.groupby('Subtopic')['Text'].apply(list)

# Print subtopic messages in order
for topic_id, messages in subtopic_groups.items():
    print(f"Subtopic {topic_id + 1}:\n")
    for message in messages:
        print(message)
    print("\n")
# Out:
# Subtopic 1:
#
# pretty much everything that you could
# possibly need to know but if you now
# they don't know these things they're the
# wrong load off so we're going to tell
# you everything that you need to know to
# make sure you're working with the right
# person so prepare to be educated on FHA
# University Christian can you tell us a
# little about them if you guys want to
# pay off your home in as little as five
# to seven years what if you could do it
# can retire even earlier want to learn
# Christian welcome how we doing good beer
# we're doing great and today is gonna be
# specific loan products so I asked you
# of you said we want to have a whole
# should be using I'd rather if you had
# but episodes like this could actually
# give you some information to be equipped
# with the lo as we call them in the
# about the FHA loan Christian let's start
# off with describing why we call it FHA
# it mean yeah so it's just the agency
# that oversees it it's the federal
# straightforward it's a primary residence
# there this is not something that you can
# home your Beach vacation home nothing
# like that has to be your primary the
# nice thing about it is that it can be a
# one to four unit so obviously the most
# creative strategy is buying a two three
# or four unit that allows you to house
# picking up a rental property via a
# the house is rental right when you have
# multiple units everybody knows and loves
# it as the three and a half percent down
# required if there is a downfall about it
# away when you hit that 80 load of value
# yeah you'd have to actually do a
# little money down nice things about it
# determined to be you know the higher
# that product convention no FHA you know
# yeah you're absolutely right there so
# you mentioned FHA stands for the federal
# is this was an illustration that was
# people from buying homes well the down
# and a half percent that's easier than
# the five percent the most conventional
# credit score that's a good point let's
# make it less of a credit score that is
# needed for someone who's getting
# basically give the difference between uh
# the minimum conventional credit score
# and the minimum FHA yeah it's it's
# margin than people think conventional is
# lower than that FHA can go down to 500
# and that's like I don't want to say
# anybody has bad credit but like 500 is
# really not good credit that's several
# standard deviations below the average
# amount yeah I'll say it that way you're
# absolutely right that's that's a Rob
# answer right there but yeah that's you
# know when you get lower than 600 though
# I don't want to say hey you got a 502
# credit score FHA loan is going to be a
# slam dunk just because something's
# easy because it could still be more
# expensive loan with the lower rates
# right or the lower credit score yeah and
# you're going to have to hurdle through
# people from being able to buy homes is
# if their debt to income ratio wasn't
# favorable maybe they had a little bit
# too much debt for the income that they
# were making so they couldn't buy a home
# there can you share what the standards
# are regarding the debts income ratios
# this is where FHA really starts to
# thrive is that it's very forgiving now
# obviously everybody should buy what's in
# their means but what's legally possible
# higher utilization of your debt to
# income ratio than conventional that
# out in that 42 to 45 percent range
# whereas FHA we've got them through as
# high as 57 which is more than half of
# to be in a specific situation to have
# it's possible you know will allow some
# buying opportunity when otherwise it
# are best for you okay tell me more about
# FHA Loans now a couple things that I'd
# a home every year FHA loan FHA loan
# rinse and repeat right that's not
# impossible but there's some obstacles to
# going to be kind of some myths around
# have one ever okay so you can buy
# product and then buy again with an FHA
# what FHA stands for it does not stand
# for first home it is not a first time
# home buyers you could use it for your
# third fourth fifth Property okay FHA
# purchase and especially when you get
# loan you can run into some trouble and
# there's two main things to look out when
# FHA loan to qualify for that house
# your old house into a rent this is
# getting into the weeds a little bit but
# I think it's important people understand
# this you're turning your old home into a
# rental that means we can credit you with
# some of the rental income to help
# house you can't use rentaling so while
# something or maybe they're moving family
# or going off to school or something so
# times Overlook because they think I'm
# just gonna buy one house a year and I'm
# gonna buy up my whole block and that
# you can't use the rental income from the
# houses you're vacating every year number
# two probably the the most misunderstood
# hit us in California when you're buying
# a three and four unit property that's it
# or duplex but when you're buying a three
# and four unit the rent events of the
# whole property together so let's say
# you're buying a fourplex all four units
# even though you're occupying one of them
# let's say two thousand dollars a unit
# would take 25 off and only credit you
# with 75 has to be more than your
# buy a four Plex you're spending one and
# a half two million dollars your payments
# are pretty much always gonna be over six
# grand so in high cost of living areas
# that made three and four unit FHA
# purchases almost impossible right people
# another thing people don't think about
# you don't have to put three and a half
# percent down that's that's all you're
# required to but you can bring in more to
# make it work 100 yeah so as rates
# more than the rents it pretty much
# invalidated FHA Loans to purchase three
# and four unit houses in like the LA's
# the New Yorks the Miami's the San
# areas it doesn't now you mentioned on
# take 25 off of the rent so it has to
# the same as saying it has to be to 1.25
# yeah after a 75 haircut it has to be one
# FHA Loans every single year to buy a
# fourplex which is what we've been
# telling people to do for the whole time
# we've been on the bus yeah that's that's
# right but you know it's a frustrating
# know single families and adus and
# duplexes three and four units have just
# become increasingly difficult to do with
# an FHA you know Christian you mentioned
# three or a four unit property assuming
# we talked about that's different than
# conventional loads right when you're
# buying a three or four unit property
# going to be 22 unit is going to be 15.
# three and a half percent down to buy
# these properties correct that's the
# will we talk about the credit not only
# will we talk about the debt's income
# utilization but the fact that the down
# very different than any other product
# you buy right two three four units are
# people are having right now is what I
# refer to as the golden handcuffs dilemma
# you bought a property with an FHA loan
# you have a killer interest rate 3.25
# 3.75 rates are going to be for uh
# seven maybe High sixes right now you
# because you're going to get a worse rate
# future properties unless you do what
# advice do you have for somebody who's
# stuck in golden handcuffs but still
# right now single family with an Adu five
# percent down conventional that's what
# product which is conventional it's five
# percent instead of three and a half so
# it's a one and a half percent down
# payment difference you know depending on
# your property size that could be like
# three four five thousand dollars right
# with opportunity to maybe convert a
# garage or an existing Adu you can still
# duplex true Triplex you know now you're
# not in that five percent down range
# class until interest rates settle and
# loans on the existing properties and you
# can keep those uh those golden handcuffs
# on for a little bit and keep those good
# rates and do you see a scenario where it
# would ever be financially advantageous
# to refinance out of a four percent FHA
# into a six and a half percent
# a half percent down on a four Plex
# future could be absolute and this is I
# flow you know everybody can focus on one
# specific property inside cash flow but
# losing the Thousand opened up the
# a win at the end of the day right
# losing that rate across your whole
# portfolio yeah that's a great point I
# mean nobody likes to pay a higher rate
# but also nobody likes to be stuck
# so sometimes you have to give something
# up to get something and if it's an
# pretty much everybody knows that couple
# usually it's about 1.8 I want to say
# unique if you ever buy with an FHA loan
# and a half percent down payment it'll be
# like 98 and that's because they charge
# you this one and a half 1.8 Point fee
# expense but in the grand scheme of
# things paying down your mortgage it is
# because your mortgage is slightly higher
# multi-family properties the two three
# and the four units which is one of the
# four unit properties must actually cash
# flow at a right around 25 percent more
# than what the expense is if you want to
# tougher in high cost of living areas but
# you're living in Manhattan or San Diego
# it's going to be tough to use an FHA
# fourplex but if you're living in
# southern states where things are a
# little bit more inexpensive or the
# Midwest areas this is almost a layup
# favorable debt to income ratio credit
# FHA loan so in most cases when someone
# says I want to buy a primary residence I
# want a house act what can I do we start
# here's a conventional option or do you
# that to buy so Christian what advice do
# Vegas is that if you're not hearing this
# advice probably talking to the wrong guy
# you need to talk to somebody who's
# knowledgeable bread products don't talk
# knows different products that can help
# you pick the one that's right for you
# and can help you get in the property
# otherwise right Christian thank you so
# knowledge regarding FHA Loans I feel
# you yep anywhere online I'm on social
# direct email me Christian
# davidgreen24.com where I have a chat
# myself right now there is like an AI
# connected with anyone that I know that
# know is this helpful are we at Bigger
# know what loan product do you want to
# to take a poll to vote for what is the
# thank you
#
#
# Subtopic 2:
#
# welcome to mortgage Mondays Today's Show
# we are going to break down an FHA loan
# show up to an appointment with the loan
# officer armed with this knowledge and
# Loans
# and speaking about education Today's
# Show is brought to you by replace your
# without earning big bucks like your guy
# David over here with replace your
# mortgage you can clear your debt build
# wealth and generate passive income in
# any economy take that monthly mortgage
# payment and put it in your pocket so you
# how head over to replace your
# university.com BP today or click the
# link in the description below to join
# the upcoming Mastermind that's once
# again replace your university.com BP
# like BiggerPockets welcome to mortgage
# Mondays this is David Green your host of
# the BiggerPockets real estate podcast
# here today with my partner and broker in
# the one brokerage Christian Bachelor
# episode one of a future series on
# guys to comment on YouTube what you
# wanted to hear and you listen and many
# episode dedicated to one specific loan
# product to really dive deep on what it
# is sounds to me like a lot of you are
# trying to figure out which load you
# that conversation with your loan officer
# with when you go have that conversation
# industry Today's show is going to be
# what does that stand for and what does
# housing Administration pretty
# only loan so that means you have to live
# use to buy an investment property a sec
# hack to a degree right but you're also
# primary residence loan because part of
# loan right so very minimal down payment
# there is lifelong mortgage insurance so
# that's an extra payment per month not
# separate it's included in your mortgage
# it never goes away yeah it doesn't go
# doesn't drop off like other loans can
# refinance to get it off and that's
# basically the insurance policy that you
# pay for the lender because you put so
# is that they have the same county loan
# limits as conventional loans so you can
# go buy up to what your county is
# Value Loan they do have high balance on
# limits same as conventional and if you
# go higher than the county loan limit
# that means that you can no longer use
# have to go into what we call jumbo loan
# so that's what the jumbo loan means 100
# housing Administration my understanding
# created to help make housing affordable
# so basically they came in they said hey
# we want to make home ownership available
# to more Americans what is stopping
# payment you're right let's make it three
# loan programs require you to have as a
# minimum doubt people well what about the
# conventional loan so can you just
# significant it's probably a much wider
# usually going to cap out 620 640. a lot
# of lenders don't want to see you go
# possible doesn't mean it's going to be
# there's underwriting criteria that
# but yes another issue that stopped
# at all so FHA Loans are more forgiving
# of getting you a loan for is a much
# typically conventional lending will cap
# your grossing which is obviously you got
# that make sense but just the fact that
# wouldn't be there right well that's what
# we're here for to help figure out what
# loans you can apply for and which ones
# like to note a lot of people say go buy
# overcome number one you can only have
# one FHA loan at a time so these are
# the FHA one you can only have one at a
# time that does not mean you can only
# refinance it out into another loan
# FHA loaned is also not stay I just said
# loan is does not have to be your first
# into buying repeatedly using the FHA
# you move out of a residence and into
# another one and when you're using the
# you're moving into there's some rules
# and number one is that typically with
# loans when you move out you're turning
# qualify you for the loan FHA has a
# really weird role that unless you move
# more than a hundred miles away from that
# that doesn't make the move impossible
# you have to make enough money to qualify
# for both mortgages at the same time if
# you don't move 100 miles away which most
# people aren't unless they get redeployed
# for work or you know repositioned or
# that's a big one that people a lot of
# gets very difficult to qualify for when
# Rule and then the least well-known one
# is the self-sufficiency rule this really
# this doesn't account for a single family
# times four that's eight grand that money
# per month after a 75 haircut so they
# mortgage and the problem in California
# is 75 of 8 000 is whatever six grand to
# would have to convert over to the
# conventional loan or just put more money
# down you know put 15 or 20 down on an
# FHA loan which doesn't make sense
# increase and now monthly payments are
# Francisco it still works in small towns
# where the rent may be more than the
# mortgage but in your big metropolitan
# that topic specifically that you have to
# meet the mortgage and the tax and the
# insurance at 75 of rents would that be
# dscr ratio math doesn't work out exactly
# probably that way but it's very similar
# yeah why that rule is there I'm not sure
# it was probably honestly Fanning man
# Freddie Mac trying to limit people using
# kind of the anti-bigger pockets rule
# one but you can still rock it with you
# that an FHA loan can be used to buy a
# it meets the self-sufficiency rule which
# with a conventional loan what's the
# minimum down payment three or fours are
# there we go and fhas you could still use
# massive advantage of FHA Loans not only
# payment doesn't change with unit account
# technically VA doesn't either but it's
# because it doesn't change the more house
# all the same so what are the issues
# primary residence probably closer to
# don't want to refi out of your FHA loan
# but you can't use the FHA loan to buy
# wants to scale their portfolio oh easy
# I'd say you go to the next best loan
# and you can still get a single family
# get a pseudo multi-family just remember
# those down payments are gonna scale when
# you get true multifamils that's true
# anymore so you go to the next closest
# loan product and the next closest asset
# you're able to you know change those
# conventional but then only put three and
# that's gonna make you more money in the
# mean these are analysis that we do with
# our borrowers all the time we take a
# look at what I call your global cash
# what if we refinanced and and lost a
# thousand dollars of cash flow from this
# property but we gained 1200 on another
# one like that's still a 200 gain and if
# opportunity to get the 1200 that's still
# because then you can still go refinance
# both of them later and drop it back so I
# I mean my answer would be yes just look
# at it globally does it impact you on a
# greater scale than what it's hurting you
# without being able to scale real estate
# expensive property and an FHA loan is
# going to save you a lot of money on the
# down payment there's a lot of meat on
# the bone the rents are going to go up
# over time you might see a scenario where
# that makes sense we also didn't really
# cover the PMI on an FHA loan is called
# MIP so a shady loan officer could sort
# of say oh no there's no PMI on this loan
# they don't tell you that there's
# actually MIP can you explain what that
# stands for again and what that is one's
# upfront and one's monthly so for FHA
# loan what a lot of people don't know is
# that you do pay your PMI every month
# hundred bucks a month after you purchase
# it's added on your marriage up front MIP
# percent of the loan amount that is
# actually added onto your loan so this is
# look at your total loan amount and look
# at your purchase price it won't be
# whatever 96.5 which is after your three
# but they finance it so it's a hidden
# cost it's a fee that the letter charges
# you to set up your mortgage insurance
# and then they finance it so it doesn't
# actually hit your pocketbook as as an
# there you go so if you don't know that
# MIP can sneak up on you and a loan
# officer can tell you there's no PMI and
# technically they're right but it's still
# deceptive which does happen a lot in
# loan industry for being honest there's
# lots of ways it's kind of a show game at
# times where you can move money from one
# place to another luckily if you use us
# you don't have to worry about that
# remember it can be used for small
# best reasons to use the FHA loan there
# is a self-sufficiency rule so three and
# use an FHA loan to buy them that's
# in some of the cheaper areas we find
# that these loans work much easier so if
# loan to get yourself a Triplex or a
# that you're going to be able to use it
# and to round it out you get a more
# score and down payment when you use the
# comes to us with the one brokerage and
# with the FHA low if you don't already
# have one that's usually what we do and
# if you do have one then we say well
# want to refinance out of the FHA and use
# you have for people that are going to
# approach their loan officer with this
# to a loan officer that just offers one
# product it's the biggest mistake people
# make I go to Chase and I get a Chase
# loan okay that's not shade at Chase
# that's just a single bank that offers a
# single luck right go somewhere that
# where you otherwise wouldn't be able to
# much for your time and sharing your
# smarter I'm sure a lot of our audience
# does as well where can people reach out
# to find more about you and connect with
# media the one broker do you want to
# theonbrokers.com that's also our website
# the onedbrokers.com and you can go to
# option that I am actually monitoring
# auto response but I still see the
# message and I will reply back once I see
# it so go check that out let me know what
# you're looking to do and I'll get you
# can help you and as a last request can
# you just go to the comment section and
# tell us what you thought of today's
# video did you learn anything you didn't
# Pockets helping you to make money in
# real estate and are you happy that Chris
# and I are here and we also would like to
# learn more about next so if you go to
# the show description you can find a link
# next loan product that you'd like us to
# break down and explain in more detail
# equipping you to move forward and make
# money with real estate if you've got
# some time check out another Bigger
# Pockets video thanks a lot love you guys
# go build some wealth
# [Music]
# [Music]

# %%
import pandas as pd
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from gensim import corpora, models

def preprocess_text(text):
    tokens = word_tokenize(text)
    tokens = [word.lower() for word in tokens if word.isalpha()]
    
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(word) for word in tokens]
    
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]
    
    return tokens

def cluster_dialogue(dataframe, num_topics=10):
    texts = [preprocess_text(text) for text in dataframe['Text']]
    dictionary = corpora.Dictionary(texts)
    corpus = [dictionary.doc2bow(text) for text in texts]
    
    lda_model = models.LdaModel(corpus, num_topics=num_topics, id2word=dictionary)
    
    topic_assignments = [max(lda_model[text], key=lambda item: item[1])[0] for text in corpus]
    topic_clusters = {}
    
    for i, topic_id in enumerate(topic_assignments):
        if topic_id not in topic_clusters:
            topic_clusters[topic_id] = []
        topic_clusters[topic_id].append(dataframe.iloc[i]['Text'])
    
    return topic_clusters

# Example DataFrame
df = transcript_df

subtopic_clusters = cluster_dialogue(df, num_topics=10)
for topic_id, messages in subtopic_clusters.items():
    print(f"Subtopic {topic_id + 1}:")
    for message in messages:
        print(message)
    print("\n")
# Out:
# Subtopic 8:
# welcome to mortgage Mondays Today's Show
# you everything that you need to know to
# without earning big bucks like your guy
# mortgage you can clear your debt build
# wealth and generate passive income in
# like BiggerPockets welcome to mortgage
# is sounds to me like a lot of you are
# with the lo as we call them in the
# housing Administration pretty
# there this is not something that you can
# refinance to get it off and that's
# housing Administration my understanding
# credit score that's a good point let's
# know when you get lower than 600 though
# easy because it could still be more
# you're going to have to hurdle through
# if their debt to income ratio wasn't
# too much debt for the income that they
# are regarding the debts income ratios
# income ratio than conventional that
# what FHA stands for it does not stand
# purchase and especially when you get
# your old house into a rent this is
# this you're turning your old home into a
# another thing people don't think about
# mortgage but in your big metropolitan
# meet the mortgage and the tax and the
# Freddie Mac trying to limit people using
# will we talk about the debt's income
# your property size that could be like
# and you can still get a single family
# get a pseudo multi-family just remember
# you're able to you know change those
# opportunity to get the 1200 that's still
# so sometimes you have to give something
# up to get something and if it's an
# of say oh no there's no PMI on this loan
# they don't tell you that there's
# stands for again and what that is one's
# that you do pay your PMI every month
# officer can tell you there's no PMI and
# favorable debt to income ratio credit
# make I go to Chase and I get a Chase
# loan okay that's not shade at Chase
# and can help you get in the property
# does as well where can people reach out
# you're looking to do and I'll get you
# tell us what you thought of today's
# go build some wealth
#
#
# Subtopic 1:
# we are going to break down an FHA loan
# wrong load off so we're going to tell
# make sure you're working with the right
# University Christian can you tell us a
# link in the description below to join
# Christian welcome how we doing good beer
# what does that stand for and what does
# it mean yeah so it's just the agency
# use to buy an investment property a sec
# it never goes away yeah it doesn't go
# away when you hit that 80 load of value
# doesn't drop off like other loans can
# limits as conventional loans so you can
# go buy up to what your county is
# limits same as conventional and if you
# yeah you're absolutely right there so
# created to help make housing affordable
# conventional loan so can you just
# the minimum conventional credit score
# margin than people think conventional is
# credit score FHA loan is going to be a
# possible doesn't mean it's going to be
# right or the lower credit score yeah and
# people from being able to buy homes is
# there can you share what the standards
# their means but what's legally possible
# buying opportunity when otherwise it
# loans you can apply for and which ones
# like to note a lot of people say go buy
# time that does not mean you can only
# loan is does not have to be your first
# rental that means we can credit you with
# some of the rental income to help
# that doesn't make the move impossible
# people aren't unless they get redeployed
# something or maybe they're moving family
# or going off to school or something so
# this doesn't account for a single family
# buy a four Plex you're spending one and
# make it work 100 yeah so as rates
# dscr ratio math doesn't work out exactly
# yeah why that rule is there I'm not sure
# become increasingly difficult to do with
# it meets the self-sufficiency rule which
# conventional loads right when you're
# because it doesn't change the more house
# people are having right now is what I
# you have a killer interest rate 3.25
# 3.75 rates are going to be for uh
# you get true multifamils that's true
# class until interest rates settle and
# loans on the existing properties and you
# look at what I call your global cash
# at it globally does it impact you on a
# mean nobody likes to pay a higher rate
# going to save you a lot of money on the
# like 98 and that's because they charge
# cost it's a fee that the letter charges
# loan industry for being honest there's
# lots of ways it's kind of a show game at
# that to buy so Christian what advice do
# you have for people that are going to
# to a loan officer that just offers one
# myself right now there is like an AI
# learn more about next so if you go to
# break down and explain in more detail
#
#
# Subtopic 6:
# pretty much everything that you could
# to seven years what if you could do it
# any economy take that monthly mortgage
# can retire even earlier want to learn
# episode one of a future series on
# episode dedicated to one specific loan
# but episodes like this could actually
# give you some information to be equipped
# off with describing why we call it FHA
# creative strategy is buying a two three
# hack to a degree right but you're also
# primary residence loan because part of
# separate it's included in your mortgage
# is this was an illustration that was
# significant it's probably a much wider
# usually going to cap out 620 640. a lot
# but yes another issue that stopped
# were making so they couldn't buy a home
# typically conventional lending will cap
# whereas FHA we've got them through as
# a home every year FHA loan FHA loan
# impossible but there's some obstacles to
# one FHA loan at a time so these are
# the FHA one you can only have one at a
# FHA loan to qualify for that house
# you're moving into there's some rules
# qualify you for the loan FHA has a
# more than a hundred miles away from that
# you have to make enough money to qualify
# for both mortgages at the same time if
# just gonna buy one house a year and I'm
# two probably the the most misunderstood
# Rule and then the least well-known one
# hit us in California when you're buying
# times four that's eight grand that money
# mortgage and the problem in California
# are pretty much always gonna be over six
# purchases almost impossible right people
# FHA loan which doesn't make sense
# more than the rents it pretty much
# that topic specifically that you have to
# take 25 off of the rent so it has to
# probably that way but it's very similar
# FHA Loans every single year to buy a
# kind of the anti-bigger pockets rule
# one but you can still rock it with you
# technically VA doesn't either but it's
# all the same so what are the issues
# seven maybe High sixes right now you
# don't want to refi out of your FHA loan
# advice do you have for somebody who's
# payment difference you know depending on
# not in that five percent down range
# flow you know everybody can focus on one
# a win at the end of the day right
# pretty much everybody knows that couple
# you to set up your mortgage insurance
# technically they're right but it's still
# times where you can move money from one
# flow at a right around 25 percent more
# FHA loan so in most cases when someone
# want a house act what can I do we start
# with the FHA low if you don't already
# have one that's usually what we do and
# much for your time and sharing your
# auto response but I still see the
# to take a poll to vote for what is the
#
#
# Subtopic 10:
# possibly need to know but if you now
# the upcoming Mastermind that's once
# that conversation with your loan officer
# only loan so that means you have to live
# pay for the lender because you put so
# so basically they came in they said hey
# standard deviations below the average
# absolutely right that's that's a Rob
# expensive loan with the lower rates
# it's possible you know will allow some
# overcome number one you can only have
# loans when you move out you're turning
# you don't move 100 miles away which most
# for work or you know repositioned or
# per month after a 75 haircut so they
# down you know put 15 or 20 down on an
# you don't have to put three and a half
# Francisco it still works in small towns
# we talked about that's different than
# refer to as the golden handcuffs dilemma
# loan product and the next closest asset
# on for a little bit and keep those good
# conventional but then only put three and
# mean these are analysis that we do with
# expensive property and an FHA loan is
# percent of the loan amount that is
# at your purchase price it won't be
# MIP can sneak up on you and a loan
# remember it can be used for small
# little bit more inexpensive or the
# Midwest areas this is almost a layup
# video did you learn anything you didn't
#
#
# Subtopic 9:
# show up to an appointment with the loan
# Show is brought to you by replace your
# little about them if you guys want to
# university.com BP today or click the
# again replace your university.com BP
# we're doing great and today is gonna be
# of you said we want to have a whole
# one to four unit so obviously the most
# picking up a rental property via a
# the house is rental right when you have
# multiple units everybody knows and loves
# that's an extra payment per month not
# Value Loan they do have high balance on
# we want to make home ownership available
# to more Americans what is stopping
# people from buying homes well the down
# payment you're right let's make it three
# make it less of a credit score that is
# there's underwriting criteria that
# favorable maybe they had a little bit
# obviously everybody should buy what's in
# FHA loaned is also not stay I just said
# for first home it is not a first time
# that's a big one that people a lot of
# times Overlook because they think I'm
# houses you're vacating every year number
# a three and four unit property that's it
# or duplex but when you're buying a three
# you're buying a fourplex all four units
# even though you're occupying one of them
# with 75 has to be more than your
# that made three and four unit FHA
# the same as saying it has to be to 1.25
# yeah after a 75 haircut it has to be one
# it was probably honestly Fanning man
# telling people to do for the whole time
# we've been on the bus yeah that's that's
# duplexes three and four units have just
# three or a four unit property assuming
# buying a three or four unit property
# minimum down payment three or fours are
# will we talk about the credit not only
# payment doesn't change with unit account
# you buy right two three four units are
# right now single family with an Adu five
# three four five thousand dollars right
# with opportunity to maybe convert a
# those down payments are gonna scale when
# our borrowers all the time we take a
# property but we gained 1200 on another
# losing the Thousand opened up the
# down payment there's a lot of meat on
# that makes sense we also didn't really
# actually MIP can you explain what that
# loan what a lot of people don't know is
# it's added on your marriage up front MIP
# look at your total loan amount and look
# you this one and a half 1.8 Point fee
# actually hit your pocketbook as as an
# deceptive which does happen a lot in
# and the four units which is one of the
# is a self-sufficiency rule so three and
# in some of the cheaper areas we find
# you need to talk to somebody who's
# that's just a single bank that offers a
# smarter I'm sure a lot of our audience
# Pockets video thanks a lot love you guys
# [Music]
# [Music]
#
#
# Subtopic 7:
# officer armed with this knowledge and
# David over here with replace your
# how head over to replace your
# specific loan products so I asked you
# with when you go have that conversation
# or four unit that allows you to house
# it as the three and a half percent down
# yeah you'd have to actually do a
# and a half percent that's easier than
# the five percent the most conventional
# needed for someone who's getting
# basically give the difference between uh
# of getting you a loan for is a much
# high as 57 which is more than half of
# your grossing which is obviously you got
# refinance it out into another loan
# loan you can run into some trouble and
# you move out of a residence and into
# another one and when you're using the
# getting into the weeds a little bit but
# really weird role that unless you move
# gets very difficult to qualify for when
# and four unit the rent events of the
# let's say two thousand dollars a unit
# grand so in high cost of living areas
# conventional loan or just put more money
# percent down that's that's all you're
# and four unit houses in like the LA's
# where the rent may be more than the
# areas it doesn't now you mentioned on
# with a conventional loan what's the
# going to be 22 unit is going to be 15.
# three and a half percent down to buy
# these properties correct that's the
# because you're going to get a worse rate
# future properties unless you do what
# percent down conventional that's what
# percent instead of three and a half so
# it's a one and a half percent down
# anymore so you go to the next closest
# to refinance out of a four percent FHA
# a half percent down on a four Plex
# future could be absolute and this is I
# specific property inside cash flow but
# thousand dollars of cash flow from this
# the bone the rents are going to go up
# upfront and one's monthly so for FHA
# multi-family properties the two three
# four unit properties must actually cash
# loan to get yourself a Triplex or a
# and to round it out you get a more
# comes to us with the one brokerage and
# knowledge regarding FHA Loans I feel
# theonbrokers.com that's also our website
# equipping you to move forward and make
# money with real estate if you've got
#
#
# Subtopic 2:
# they don't know these things they're the
# and speaking about education Today's
# here today with my partner and broker in
# about the FHA loan Christian let's start
# straightforward it's a primary residence
# there is lifelong mortgage insurance so
# determined to be you know the higher
# that product convention no FHA you know
# you mentioned FHA stands for the federal
# of lenders don't want to see you go
# and that's like I don't want to say
# answer right there but yeah that's you
# I don't want to say hey you got a 502
# slam dunk just because something's
# out in that 42 to 45 percent range
# rinse and repeat right that's not
# and number one is that typically with
# whole property together so let's say
# would take 25 off and only credit you
# a half two million dollars your payments
# increase and now monthly payments are
# right but you know it's a frustrating
# an FHA you know Christian you mentioned
# very different than any other product
# primary residence probably closer to
# garage or an existing Adu you can still
# duplex true Triplex you know now you're
# would ever be financially advantageous
# into a six and a half percent
# I mean my answer would be yes just look
# but also nobody likes to be stuck
# usually it's about 1.8 I want to say
# and a half percent down payment it'll be
# there you go so if you don't know that
# southern states where things are a
# says I want to buy a primary residence I
# here's a conventional option or do you
# approach their loan officer with this
# knows different products that can help
# you pick the one that's right for you
# media the one broker do you want to
# direct email me Christian
# davidgreen24.com where I have a chat
# option that I am actually monitoring
# it so go check that out let me know what
# can help you and as a last request can
# know is this helpful are we at Bigger
# and I are here and we also would like to
# know what loan product do you want to
# next loan product that you'd like us to
#
#
# Subtopic 3:
# person so prepare to be educated on FHA
# pay off your home in as little as five
# guys to comment on YouTube what you
# trying to figure out which load you
# should be using I'd rather if you had
# industry Today's show is going to be
# home your Beach vacation home nothing
# like that has to be your primary the
# nice thing about it is that it can be a
# basically the insurance policy that you
# little money down nice things about it
# lower than that FHA can go down to 500
# anybody has bad credit but like 500 is
# this is where FHA really starts to
# third fourth fifth Property okay FHA
# into buying repeatedly using the FHA
# house you can't use rentaling so while
# gonna buy up my whole block and that
# is 75 of 8 000 is whatever six grand to
# invalidated FHA Loans to purchase three
# fourplex which is what we've been
# know single families and adus and
# massive advantage of FHA Loans not only
# that's gonna make you more money in the
# both of them later and drop it back so I
# losing that rate across your whole
# whatever 96.5 which is after your three
# and then they finance it so it doesn't
# things paying down your mortgage it is
# tougher in high cost of living areas but
# advice probably talking to the wrong guy
# to find more about you and connect with
# message and I will reply back once I see
# the show description you can find a link
#
#
# Subtopic 4:
# Loans
# payment and put it in your pocket so you
# Mondays this is David Green your host of
# loan right so very minimal down payment
# that means that you can no longer use
# so that's what the jumbo loan means 100
# loan programs require you to have as a
# minimum doubt people well what about the
# and the minimum FHA yeah it's it's
# at all so FHA Loans are more forgiving
# thrive is that it's very forgiving now
# wouldn't be there right well that's what
# are best for you okay tell me more about
# going to be kind of some myths around
# have one ever okay so you can buy
# product and then buy again with an FHA
# home buyers you could use it for your
# there's two main things to look out when
# you can't use the rental income from the
# would have to convert over to the
# the New Yorks the Miami's the San
# that an FHA loan can be used to buy a
# there we go and fhas you could still use
# you bought a property with an FHA loan
# but you can't use the FHA loan to buy
# stuck in golden handcuffs but still
# wants to scale their portfolio oh easy
# I'd say you go to the next best loan
# can keep those uh those golden handcuffs
# what if we refinanced and and lost a
# one like that's still a 200 gain and if
# greater scale than what it's hurting you
# portfolio yeah that's a great point I
# without being able to scale real estate
# hundred bucks a month after you purchase
# unique if you ever buy with an FHA loan
# expense but in the grand scheme of
# best reasons to use the FHA loan there
# than what the expense is if you want to
# use an FHA loan to buy them that's
# that these loans work much easier so if
# it's going to be tough to use an FHA
# that you're going to be able to use it
# score and down payment when you use the
# if you do have one then we say well
# want to refinance out of the FHA and use
# some time check out another Bigger
#
#
# Subtopic 5:
# the BiggerPockets real estate podcast
# the one brokerage Christian Bachelor
# wanted to hear and you listen and many
# product to really dive deep on what it
# that oversees it it's the federal
# required if there is a downfall about it
# is that they have the same county loan
# go higher than the county loan limit
# have to go into what we call jumbo loan
# really not good credit that's several
# amount yeah I'll say it that way you're
# higher utilization of your debt to
# to be in a specific situation to have
# that make sense but just the fact that
# we're here for to help figure out what
# FHA Loans now a couple things that I'd
# I think it's important people understand
# is the self-sufficiency rule this really
# required to but you can bring in more to
# insurance at 75 of rents would that be
# utilization but the fact that the down
# product which is conventional it's five
# rates and do you see a scenario where it
# because then you can still go refinance
# over time you might see a scenario where
# cover the PMI on an FHA loan is called
# MIP so a shady loan officer could sort
# actually added onto your loan so this is
# but they finance it so it's a hidden
# because your mortgage is slightly higher
# place to another luckily if you use us
# you don't have to worry about that
# you're living in Manhattan or San Diego
# fourplex but if you're living in
# Vegas is that if you're not hearing this
# knowledgeable bread products don't talk
# product it's the biggest mistake people
# single luck right go somewhere that
# where you otherwise wouldn't be able to
# otherwise right Christian thank you so
# you yep anywhere online I'm on social
# the onedbrokers.com and you can go to
# connected with anyone that I know that
# you just go to the comment section and
# Pockets helping you to make money in
# real estate and are you happy that Chris
# thank you

# %%
subtopic_clusters
# Out:
# {7: ["welcome to mortgage Mondays Today's Show",
#   'you everything that you need to know to',
#   'without earning big bucks like your guy',
#   'mortgage you can clear your debt build',
#   'wealth and generate passive income in',
#   'like BiggerPockets welcome to mortgage',
#   'is sounds to me like a lot of you are',
#   'with the lo as we call them in the',
#   'housing Administration pretty',
#   'there this is not something that you can',
#   "refinance to get it off and that's",
#   'housing Administration my understanding',
#   "credit score that's a good point let's",
#   'know when you get lower than 600 though',
#   'easy because it could still be more',
#   "you're going to have to hurdle through",
#   "if their debt to income ratio wasn't",
#   'too much debt for the income that they',
#   'are regarding the debts income ratios',
#   'income ratio than conventional that',
#   'what FHA stands for it does not stand',
#   'purchase and especially when you get',
#   'your old house into a rent this is',
#   "this you're turning your old home into a",
#   "another thing people don't think about",
#   'mortgage but in your big metropolitan',
#   'meet the mortgage and the tax and the',
#   'Freddie Mac trying to limit people using',
#   "will we talk about the debt's income",
#   'your property size that could be like',
#   'and you can still get a single family',
#   'get a pseudo multi-family just remember',
#   "you're able to you know change those",
#   "opportunity to get the 1200 that's still",
#   'so sometimes you have to give something',
#   "up to get something and if it's an",
#   "of say oh no there's no PMI on this loan",
#   "they don't tell you that there's",
#   "stands for again and what that is one's",
#   'that you do pay your PMI every month',
#   "officer can tell you there's no PMI and",
#   'favorable debt to income ratio credit',
#   'make I go to Chase and I get a Chase',
#   "loan okay that's not shade at Chase",
#   'and can help you get in the property',
#   'does as well where can people reach out',
#   "you're looking to do and I'll get you",
#   "tell us what you thought of today's",
#   'go build some wealth'],
#  0: ['we are going to break down an FHA loan',
#   "wrong load off so we're going to tell",
#   "make sure you're working with the right",
#   'University Christian can you tell us a',
#   'link in the description below to join',
#   'Christian welcome how we doing good beer',
#   'what does that stand for and what does',
#   "it mean yeah so it's just the agency",
#   'use to buy an investment property a sec',
#   "it never goes away yeah it doesn't go",
#   'away when you hit that 80 load of value',
#   "doesn't drop off like other loans can",
#   'limits as conventional loans so you can',
#   'go buy up to what your county is',
#   'limits same as conventional and if you',
#   "yeah you're absolutely right there so",
#   'created to help make housing affordable',
#   'conventional loan so can you just',
#   'the minimum conventional credit score',
#   'margin than people think conventional is',
#   'credit score FHA loan is going to be a',
#   "possible doesn't mean it's going to be",
#   'right or the lower credit score yeah and',
#   'people from being able to buy homes is',
#   'there can you share what the standards',
#   "their means but what's legally possible",
#   'buying opportunity when otherwise it',
#   'loans you can apply for and which ones',
#   'like to note a lot of people say go buy',
#   'time that does not mean you can only',
#   'loan is does not have to be your first',
#   'rental that means we can credit you with',
#   'some of the rental income to help',
#   "that doesn't make the move impossible",
#   "people aren't unless they get redeployed",
#   "something or maybe they're moving family",
#   'or going off to school or something so',
#   "this doesn't account for a single family",
#   "buy a four Plex you're spending one and",
#   'make it work 100 yeah so as rates',
#   "dscr ratio math doesn't work out exactly",
#   "yeah why that rule is there I'm not sure",
#   'become increasingly difficult to do with',
#   'it meets the self-sufficiency rule which',
#   "conventional loads right when you're",
#   "because it doesn't change the more house",
#   'people are having right now is what I',
#   'you have a killer interest rate 3.25',
#   '3.75 rates are going to be for uh',
#   "you get true multifamils that's true",
#   'class until interest rates settle and',
#   'loans on the existing properties and you',
#   'look at what I call your global cash',
#   'at it globally does it impact you on a',
#   'mean nobody likes to pay a higher rate',
#   'going to save you a lot of money on the',
#   "like 98 and that's because they charge",
#   "cost it's a fee that the letter charges",
#   "loan industry for being honest there's",
#   "lots of ways it's kind of a show game at",
#   'that to buy so Christian what advice do',
#   'you have for people that are going to',
#   'to a loan officer that just offers one',
#   'myself right now there is like an AI',
#   'learn more about next so if you go to',
#   'break down and explain in more detail'],
#  5: ['pretty much everything that you could',
#   'to seven years what if you could do it',
#   'any economy take that monthly mortgage',
#   'can retire even earlier want to learn',
#   'episode one of a future series on',
#   'episode dedicated to one specific loan',
#   'but episodes like this could actually',
#   'give you some information to be equipped',
#   'off with describing why we call it FHA',
#   'creative strategy is buying a two three',
#   "hack to a degree right but you're also",
#   'primary residence loan because part of',
#   "separate it's included in your mortgage",
#   'is this was an illustration that was',
#   "significant it's probably a much wider",
#   'usually going to cap out 620 640. a lot',
#   'but yes another issue that stopped',
#   "were making so they couldn't buy a home",
#   'typically conventional lending will cap',
#   "whereas FHA we've got them through as",
#   'a home every year FHA loan FHA loan',
#   "impossible but there's some obstacles to",
#   'one FHA loan at a time so these are',
#   'the FHA one you can only have one at a',
#   'FHA loan to qualify for that house',
#   "you're moving into there's some rules",
#   'qualify you for the loan FHA has a',
#   'more than a hundred miles away from that',
#   'you have to make enough money to qualify',
#   'for both mortgages at the same time if',
#   "just gonna buy one house a year and I'm",
#   'two probably the the most misunderstood',
#   'Rule and then the least well-known one',
#   "hit us in California when you're buying",
#   "times four that's eight grand that money",
#   'mortgage and the problem in California',
#   'are pretty much always gonna be over six',
#   'purchases almost impossible right people',
#   "FHA loan which doesn't make sense",
#   'more than the rents it pretty much',
#   'that topic specifically that you have to',
#   'take 25 off of the rent so it has to',
#   "probably that way but it's very similar",
#   'FHA Loans every single year to buy a',
#   'kind of the anti-bigger pockets rule',
#   'one but you can still rock it with you',
#   "technically VA doesn't either but it's",
#   'all the same so what are the issues',
#   'seven maybe High sixes right now you',
#   "don't want to refi out of your FHA loan",
#   "advice do you have for somebody who's",
#   'payment difference you know depending on',
#   'not in that five percent down range',
#   'flow you know everybody can focus on one',
#   'a win at the end of the day right',
#   'pretty much everybody knows that couple',
#   'you to set up your mortgage insurance',
#   "technically they're right but it's still",
#   'times where you can move money from one',
#   'flow at a right around 25 percent more',
#   'FHA loan so in most cases when someone',
#   'want a house act what can I do we start',
#   "with the FHA low if you don't already",
#   "have one that's usually what we do and",
#   'much for your time and sharing your',
#   'auto response but I still see the',
#   'to take a poll to vote for what is the'],
#  9: ['possibly need to know but if you now',
#   "the upcoming Mastermind that's once",
#   'that conversation with your loan officer',
#   'only loan so that means you have to live',
#   'pay for the lender because you put so',
#   'so basically they came in they said hey',
#   'standard deviations below the average',
#   "absolutely right that's that's a Rob",
#   'expensive loan with the lower rates',
#   "it's possible you know will allow some",
#   'overcome number one you can only have',
#   "loans when you move out you're turning",
#   "you don't move 100 miles away which most",
#   'for work or you know repositioned or',
#   'per month after a 75 haircut so they',
#   'down you know put 15 or 20 down on an',
#   "you don't have to put three and a half",
#   'Francisco it still works in small towns',
#   "we talked about that's different than",
#   'refer to as the golden handcuffs dilemma',
#   'loan product and the next closest asset',
#   'on for a little bit and keep those good',
#   'conventional but then only put three and',
#   'mean these are analysis that we do with',
#   'expensive property and an FHA loan is',
#   'percent of the loan amount that is',
#   "at your purchase price it won't be",
#   'MIP can sneak up on you and a loan',
#   'remember it can be used for small',
#   'little bit more inexpensive or the',
#   'Midwest areas this is almost a layup',
#   "video did you learn anything you didn't"],
#  8: ['show up to an appointment with the loan',
#   'Show is brought to you by replace your',
#   'little about them if you guys want to',
#   'university.com BP today or click the',
#   'again replace your university.com BP',
#   "we're doing great and today is gonna be",
#   'of you said we want to have a whole',
#   'one to four unit so obviously the most',
#   'picking up a rental property via a',
#   'the house is rental right when you have',
#   'multiple units everybody knows and loves',
#   "that's an extra payment per month not",
#   'Value Loan they do have high balance on',
#   'we want to make home ownership available',
#   'to more Americans what is stopping',
#   'people from buying homes well the down',
#   "payment you're right let's make it three",
#   'make it less of a credit score that is',
#   "there's underwriting criteria that",
#   'favorable maybe they had a little bit',
#   "obviously everybody should buy what's in",
#   'FHA loaned is also not stay I just said',
#   'for first home it is not a first time',
#   "that's a big one that people a lot of",
#   "times Overlook because they think I'm",
#   "houses you're vacating every year number",
#   "a three and four unit property that's it",
#   "or duplex but when you're buying a three",
#   "you're buying a fourplex all four units",
#   "even though you're occupying one of them",
#   'with 75 has to be more than your',
#   'that made three and four unit FHA',
#   'the same as saying it has to be to 1.25',
#   'yeah after a 75 haircut it has to be one',
#   'it was probably honestly Fanning man',
#   'telling people to do for the whole time',
#   "we've been on the bus yeah that's that's",
#   'duplexes three and four units have just',
#   'three or a four unit property assuming',
#   'buying a three or four unit property',
#   'minimum down payment three or fours are',
#   'will we talk about the credit not only',
#   "payment doesn't change with unit account",
#   'you buy right two three four units are',
#   'right now single family with an Adu five',
#   'three four five thousand dollars right',
#   'with opportunity to maybe convert a',
#   'those down payments are gonna scale when',
#   'our borrowers all the time we take a',
#   'property but we gained 1200 on another',
#   'losing the Thousand opened up the',
#   "down payment there's a lot of meat on",
#   "that makes sense we also didn't really",
#   'actually MIP can you explain what that',
#   "loan what a lot of people don't know is",
#   "it's added on your marriage up front MIP",
#   'look at your total loan amount and look',
#   'you this one and a half 1.8 Point fee',
#   'actually hit your pocketbook as as an',
#   'deceptive which does happen a lot in',
#   'and the four units which is one of the',
#   'is a self-sufficiency rule so three and',
#   'in some of the cheaper areas we find',
#   "you need to talk to somebody who's",
#   "that's just a single bank that offers a",
#   "smarter I'm sure a lot of our audience",
#   'Pockets video thanks a lot love you guys',
#   '[Music]',
#   '[Music]'],
#  6: ['officer armed with this knowledge and',
#   'David over here with replace your',
#   'how head over to replace your',
#   'specific loan products so I asked you',
#   'with when you go have that conversation',
#   'or four unit that allows you to house',
#   'it as the three and a half percent down',
#   "yeah you'd have to actually do a",
#   "and a half percent that's easier than",
#   'the five percent the most conventional',
#   "needed for someone who's getting",
#   'basically give the difference between uh',
#   'of getting you a loan for is a much',
#   'high as 57 which is more than half of',
#   'your grossing which is obviously you got',
#   'refinance it out into another loan',
#   'loan you can run into some trouble and',
#   'you move out of a residence and into',
#   "another one and when you're using the",
#   'getting into the weeds a little bit but',
#   'really weird role that unless you move',
#   'gets very difficult to qualify for when',
#   'and four unit the rent events of the',
#   "let's say two thousand dollars a unit",
#   'grand so in high cost of living areas',
#   'conventional loan or just put more money',
#   "percent down that's that's all you're",
#   "and four unit houses in like the LA's",
#   'where the rent may be more than the',
#   "areas it doesn't now you mentioned on",
#   "with a conventional loan what's the",
#   'going to be 22 unit is going to be 15.',
#   'three and a half percent down to buy',
#   "these properties correct that's the",
#   "because you're going to get a worse rate",
#   'future properties unless you do what',
#   "percent down conventional that's what",
#   'percent instead of three and a half so',
#   "it's a one and a half percent down",
#   'anymore so you go to the next closest',
#   'to refinance out of a four percent FHA',
#   'a half percent down on a four Plex',
#   'future could be absolute and this is I',
#   'specific property inside cash flow but',
#   'thousand dollars of cash flow from this',
#   'the bone the rents are going to go up',
#   "upfront and one's monthly so for FHA",
#   'multi-family properties the two three',
#   'four unit properties must actually cash',
#   'loan to get yourself a Triplex or a',
#   'and to round it out you get a more',
#   'comes to us with the one brokerage and',
#   'knowledge regarding FHA Loans I feel',
#   "theonbrokers.com that's also our website",
#   'equipping you to move forward and make',
#   "money with real estate if you've got"],
#  1: ["they don't know these things they're the",
#   "and speaking about education Today's",
#   'here today with my partner and broker in',
#   "about the FHA loan Christian let's start",
#   "straightforward it's a primary residence",
#   'there is lifelong mortgage insurance so',
#   'determined to be you know the higher',
#   'that product convention no FHA you know',
#   'you mentioned FHA stands for the federal',
#   "of lenders don't want to see you go",
#   "and that's like I don't want to say",
#   "answer right there but yeah that's you",
#   "I don't want to say hey you got a 502",
#   "slam dunk just because something's",
#   'out in that 42 to 45 percent range',
#   "rinse and repeat right that's not",
#   'and number one is that typically with',
#   "whole property together so let's say",
#   'would take 25 off and only credit you',
#   'a half two million dollars your payments',
#   'increase and now monthly payments are',
#   "right but you know it's a frustrating",
#   'an FHA you know Christian you mentioned',
#   'very different than any other product',
#   'primary residence probably closer to',
#   'garage or an existing Adu you can still',
#   "duplex true Triplex you know now you're",
#   'would ever be financially advantageous',
#   'into a six and a half percent',
#   'I mean my answer would be yes just look',
#   'but also nobody likes to be stuck',
#   "usually it's about 1.8 I want to say",
#   "and a half percent down payment it'll be",
#   "there you go so if you don't know that",
#   'southern states where things are a',
#   'says I want to buy a primary residence I',
#   "here's a conventional option or do you",
#   'approach their loan officer with this',
#   'knows different products that can help',
#   "you pick the one that's right for you",
#   'media the one broker do you want to',
#   'direct email me Christian',
#   'davidgreen24.com where I have a chat',
#   'option that I am actually monitoring',
#   'it so go check that out let me know what',
#   'can help you and as a last request can',
#   'know is this helpful are we at Bigger',
#   'and I are here and we also would like to',
#   'know what loan product do you want to',
#   "next loan product that you'd like us to"],
#  2: ['person so prepare to be educated on FHA',
#   'pay off your home in as little as five',
#   'guys to comment on YouTube what you',
#   'trying to figure out which load you',
#   "should be using I'd rather if you had",
#   "industry Today's show is going to be",
#   'home your Beach vacation home nothing',
#   'like that has to be your primary the',
#   'nice thing about it is that it can be a',
#   'basically the insurance policy that you',
#   'little money down nice things about it',
#   'lower than that FHA can go down to 500',
#   'anybody has bad credit but like 500 is',
#   'this is where FHA really starts to',
#   'third fourth fifth Property okay FHA',
#   'into buying repeatedly using the FHA',
#   "house you can't use rentaling so while",
#   'gonna buy up my whole block and that',
#   'is 75 of 8 000 is whatever six grand to',
#   'invalidated FHA Loans to purchase three',
#   "fourplex which is what we've been",
#   'know single families and adus and',
#   'massive advantage of FHA Loans not only',
#   "that's gonna make you more money in the",
#   'both of them later and drop it back so I',
#   'losing that rate across your whole',
#   'whatever 96.5 which is after your three',
#   "and then they finance it so it doesn't",
#   'things paying down your mortgage it is',
#   'tougher in high cost of living areas but',
#   'advice probably talking to the wrong guy',
#   'to find more about you and connect with',
#   'message and I will reply back once I see',
#   'the show description you can find a link'],
#  3: ['Loans',
#   'payment and put it in your pocket so you',
#   'Mondays this is David Green your host of',
#   'loan right so very minimal down payment',
#   'that means that you can no longer use',
#   "so that's what the jumbo loan means 100",
#   'loan programs require you to have as a',
#   'minimum doubt people well what about the',
#   "and the minimum FHA yeah it's it's",
#   'at all so FHA Loans are more forgiving',
#   "thrive is that it's very forgiving now",
#   "wouldn't be there right well that's what",
#   'are best for you okay tell me more about',
#   'going to be kind of some myths around',
#   'have one ever okay so you can buy',
#   'product and then buy again with an FHA',
#   'home buyers you could use it for your',
#   "there's two main things to look out when",
#   "you can't use the rental income from the",
#   'would have to convert over to the',
#   "the New Yorks the Miami's the San",
#   'that an FHA loan can be used to buy a',
#   'there we go and fhas you could still use',
#   'you bought a property with an FHA loan',
#   "but you can't use the FHA loan to buy",
#   'stuck in golden handcuffs but still',
#   'wants to scale their portfolio oh easy',
#   "I'd say you go to the next best loan",
#   'can keep those uh those golden handcuffs',
#   'what if we refinanced and and lost a',
#   "one like that's still a 200 gain and if",
#   "greater scale than what it's hurting you",
#   "portfolio yeah that's a great point I",
#   'without being able to scale real estate',
#   'hundred bucks a month after you purchase',
#   'unique if you ever buy with an FHA loan',
#   'expense but in the grand scheme of',
#   'best reasons to use the FHA loan there',
#   'than what the expense is if you want to',
#   "use an FHA loan to buy them that's",
#   'that these loans work much easier so if',
#   "it's going to be tough to use an FHA",
#   "that you're going to be able to use it",
#   'score and down payment when you use the',
#   'if you do have one then we say well',
#   'want to refinance out of the FHA and use',
#   'some time check out another Bigger'],
#  4: ['the BiggerPockets real estate podcast',
#   'the one brokerage Christian Bachelor',
#   'wanted to hear and you listen and many',
#   'product to really dive deep on what it',
#   "that oversees it it's the federal",
#   'required if there is a downfall about it',
#   'is that they have the same county loan',
#   'go higher than the county loan limit',
#   'have to go into what we call jumbo loan',
#   "really not good credit that's several",
#   "amount yeah I'll say it that way you're",
#   'higher utilization of your debt to',
#   'to be in a specific situation to have',
#   'that make sense but just the fact that',
#   "we're here for to help figure out what",
#   "FHA Loans now a couple things that I'd",
#   "I think it's important people understand",
#   'is the self-sufficiency rule this really',
#   'required to but you can bring in more to',
#   'insurance at 75 of rents would that be',
#   'utilization but the fact that the down',
#   "product which is conventional it's five",
#   'rates and do you see a scenario where it',
#   'because then you can still go refinance',
#   'over time you might see a scenario where',
#   'cover the PMI on an FHA loan is called',
#   'MIP so a shady loan officer could sort',
#   'actually added onto your loan so this is',
#   "but they finance it so it's a hidden",
#   'because your mortgage is slightly higher',
#   'place to another luckily if you use us',
#   "you don't have to worry about that",
#   "you're living in Manhattan or San Diego",
#   "fourplex but if you're living in",
#   "Vegas is that if you're not hearing this",
#   "knowledgeable bread products don't talk",
#   "product it's the biggest mistake people",
#   'single luck right go somewhere that',
#   "where you otherwise wouldn't be able to",
#   'otherwise right Christian thank you so',
#   "you yep anywhere online I'm on social",
#   'the onedbrokers.com and you can go to',
#   'connected with anyone that I know that',
#   'you just go to the comment section and',
#   'Pockets helping you to make money in',
#   'real estate and are you happy that Chris',
#   'thank you']}

# %% [markdown]
# # Text ranking

# %%
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.text_rank import TextRankSummarizer


# Example subtopic data
subtopic_data = subtopic_clusters

# Apply TextRank summarization to each subtopic
for subtopic_id, messages in subtopic_data.items():
    subtopic_text = '. '.join(messages)
    
    parser = PlaintextParser.from_string(subtopic_text, Tokenizer("english"))
    summarizer = TextRankSummarizer()
    
    print(f"Subtopic {subtopic_id + 1} Summary:")
    for sentence in summarizer(parser.document, 5):  # Adjust the number of sentences as needed
        print(sentence)
    
    print("\n")
# Out:
# Subtopic 1 Summary:
# yeah you'd have to actually do a. basically the insurance policy that you.
# the FHA one you can only have one at a. have one ever okay so you can buy.
# qualify you for the loan FHA has a. really weird role that unless you move.
# future could be absolute and this is I. our borrowers all the time we take a. what if we refinanced and and lost a. property but we gained 1200 on another.
# you pick the one that's right for you.
#
#
# Subtopic 2 Summary:
# you everything that you need to know to.
# nice thing about it is that it can be a. or four unit that allows you to house.
# at it globally does it impact you on a. greater scale than what it's hurting you.
# and to round it out you get a more.
# you're looking to do and I'll get you.

# %% [markdown]
# # Processed into timeline and make a short video

# %%
# Original

from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.text_rank import TextRankSummarizer

# Combine all sentences into one paragraph
text = '. '.join(transcript_df['Text'])

# Parsing the text
parser = PlaintextParser.from_string(text, Tokenizer("english"))

# Applying TextRank
summarizer = TextRankSummarizer()
summary = summarizer(parser.document, 10)  # Here, we're extracting 3 sentences. Adjust as needed.

# Extracted sentences
for sentence in summary:
    print(sentence)
# Out:
# you everything that you need to know to.
# nice thing about it is that it can be a. one to four unit so obviously the most.
# yeah you'd have to actually do a. refinance to get it off and that's.
# lower than that FHA can go down to 500. and that's like I don't want to say.
# I don't want to say hey you got a 502. credit score FHA loan is going to be a. slam dunk just because something's.
# the FHA one you can only have one at a. time that does not mean you can only.
# qualify you for the loan FHA has a. really weird role that unless you move.
# going to be 22 unit is going to be 15.. there we go and fhas you could still use.
# that you're going to be able to use it.
# you pick the one that's right for you.

# %%
df = transcript_df
# Mapping sentences to their timestamps
for sentence in summary:
    sentence_str = str(sentence)
    idx = df[df['Text'] == sentence_str].index[0]
    start_time = df.iloc[idx]['Start']
    end_time = df.iloc[idx]['End']
    print(f"{start_time} to {end_time}: {sentence_str}")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 5
#       3 for sentence in summary:
#       4     sentence_str = str(sentence)
# ----> 5     idx = df[df['Text'] == sentence_str].index[0]
#       6     start_time = df.iloc[idx]['Start']
#       7     end_time = df.iloc[idx]['End']
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5320, in Index.__getitem__(self, key)
#    5317 if is_integer(key) or is_float(key):
#    5318     # GH#44051 exclude bool, which would return a 2d ndarray
#    5319     key = com.cast_scalar_indexer(key, warn_float=True)
# -> 5320     return getitem(key)
#    5322 if isinstance(key, slice):
#    5323     # This case is separated from the conditional above to avoid
#    5324     # pessimization com.is_bool_indexer and ndim checks.
#    5325     result = getitem(key)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
# Out:
# Requirement already satisfied: pandas in c:\users\drago\anaconda3\lib\site-packages (1.5.3)
# Collecting sumy
#   Downloading sumy-0.11.0-py2.py3-none-any.whl (97 kB)
#      ---------------------------------------- 97.3/97.3 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\drago\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\drago\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\drago\anaconda3\lib\site-packages (from pandas) (1.23.5)
# Collecting docopt<0.7,>=0.6.1
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pycountry>=18.2.23
#   Downloading pycountry-22.3.5.tar.gz (10.1 MB)
#      --------------------------------------- 10.1/10.1 MB 14.4 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting breadability>=0.1.20
#   Downloading breadability-0.1.20.tar.gz (32 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: requests>=2.7.0 in c:\users\drago\anaconda3\lib\site-packages (from sumy) (2.28.1)
# Requirement already satisfied: nltk>=3.0.2 in c:\users\drago\anaconda3\lib\site-packages (from sumy) (3.7)
# Requirement already satisfied: chardet in c:\users\drago\anaconda3\lib\site-packages (from breadability>=0.1.20->sumy) (4.0.0)
# Requirement already satisfied: lxml>=2.0 in c:\users\drago\anaconda3\lib\site-packages (from breadability>=0.1.20->sumy) (4.9.1)
# Requirement already satisfied: joblib in c:\users\drago\anaconda3\lib\site-packages (from nltk>=3.0.2->sumy) (1.1.1)
# Requirement already satisfied: tqdm in c:\users\drago\anaconda3\lib\site-packages (from nltk>=3.0.2->sumy) (4.64.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\drago\anaconda3\lib\site-packages (from nltk>=3.0.2->sumy) (2022.7.9)
# Requirement already satisfied: click in c:\users\drago\anaconda3\lib\site-packages (from nltk>=3.0.2->sumy) (8.0.4)
# Requirement already satisfied: setuptools in c:\users\drago\anaconda3\lib\site-packages (from pycountry>=18.2.23->sumy) (65.6.3)
# Requirement already satisfied: six>=1.5 in c:\users\drago\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\drago\anaconda3\lib\site-packages (from requests>=2.7.0->sumy) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\drago\anaconda3\lib\site-packages (from requests>=2.7.0->sumy) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\drago\anaconda3\lib\site-packages (from requests>=2.7.0->sumy) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\drago\anaconda3\lib\site-packages (from requests>=2.7.0->sumy) (2.0.4)
# Requirement already satisfied: colorama in c:\users\drago\anaconda3\lib\site-packages (from click->nltk>=3.0.2->sumy) (0.4.6)
# Building wheels for collected packages: breadability, docopt, pycountry
#   Building wheel for breadability (setup.py): started
#   Building wheel for breadability (setup.py): finished with status 'done'
#   Created wheel for breadability: filename=breadability-0.1.20-py2.py3-none-any.whl size=21743 sha256=b579045bff3fafec2af49860221bf489b075778cd8e058397811d14f99da871e
#   Stored in directory: c:\users\drago\appdata\local\pip\cache\wheels\7d\b9\d8\8400bd0cf7e2592863d57dc72ea1045b5ed428149cf72a2dd0
#   Building wheel for docopt (setup.py): started
#   Building wheel for docopt (setup.py): finished with status 'done'
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13775 sha256=d74b4dae659610cd4c1621d70061f3d58bb4ea8ad1811acbd9456d0184225506
#   Stored in directory: c:\users\drago\appdata\local\pip\cache\wheels\7c\d7\8d\2156234738063e3d4a39ba77dc677046100e62766b53807189
#   Building wheel for pycountry (pyproject.toml): started
#   Building wheel for pycountry (pyproject.toml): finished with status 'done'
#   Created wheel for pycountry: filename=pycountry-22.3.5-py2.py3-none-any.whl size=10681895 sha256=30a0fe713ff189fc4f6b3f35ef2aa0f769cee9a7ec195b4f1e759655cab567ab
#   Stored in directory: c:\users\drago\appdata\local\pip\cache\wheels\62\4a\9c\7a46699df9efb845aa116fae5e52d8690fc442fef6d32213f7
# Successfully built breadability docopt pycountry
# Installing collected packages: docopt, pycountry, breadability, sumy
# Successfully installed breadability-0.1.20 docopt-0.6.2 pycountry-22.3.5 sumy-0.11.0
