# %%
from youtube_transcript_api import YouTubeTranscriptApi
import pandas as pd


def get_youtube_video_transcript_dataframe(youtube_url):
    try:
        # Extract video ID from the URL
        video_id = youtube_url.split("v=")[-1]

        # Get the transcript
        transcript = YouTubeTranscriptApi.get_transcript(video_id)

        # Create an empty list to store the transcript data
        transcript_data = []

        # Loop through each transcript item and extract timestamp and text
        for item in transcript:
            start_time = item["start"]
            end_time = item["start"] + item["duration"]
            text = item["text"]
            transcript_data.append({"Start": start_time, "End": end_time, "Text": text})

        # Convert the list to a pandas DataFrame
        df = pd.DataFrame(transcript_data)

        return df

    except Exception as e:
        print("Error:", e)
        return None

# Replace the following with the YouTube video URL of your choice
youtube_url = "https://www.youtube.com/watch?v=VyFk2sdw230&ab_channel=BiggerPockets"
transcript_df = get_youtube_video_transcript_dataframe(youtube_url)

if transcript_df is not None:
    print(transcript_df.head())
else:
    print("Failed to get the transcript.")
# Out:
#    Start     End                                      Text
# 0  0.000   5.339  welcome to mortgage Mondays Today's Show
# 1  2.280   6.720    we are going to break down an FHA loan
# 2  5.339   8.280     pretty much everything that you could
# 3  6.720   9.720      possibly need to know but if you now
# 4  8.280  10.980   show up to an appointment with the loan

# %% [markdown]
# # Preprocessed

# %%
df = transcript_df

# Combine rows in groups of 10
combined_rows = []
group_size = 10
num_groups = (len(df) + group_size - 1) // group_size  # Calculate the number of groups

for i in range(num_groups):
    start_idx = i * group_size
    end_idx = min(start_idx + group_size, len(df)) - 1  # Handle last group with fewer than 10 rows
    start_text = df.loc[start_idx, 'Text']
    end_text = df.loc[end_idx, 'Text']
    combined_text = ' '.join(df.loc[start_idx:end_idx, 'Text'])
    combined_rows.append({'Start': df.loc[start_idx, 'Start'], 'End': df.loc[end_idx, 'End'], 'Text': combined_text})

# Create a new DataFrame with combined rows
combined_df = pd.DataFrame(combined_rows)

combined_df.head()
# Out:
#     Start     End                                               Text
# 0   0.000  19.260  welcome to mortgage Mondays Today's Show we ar...
# 1  16.260  35.579  person so prepare to be educated on FHA Loans ...
# 2  33.899  56.520  mortgage you can clear your debt build wealth ...
# 3  54.059  77.400  like BiggerPockets welcome to mortgage Mondays...
# 4  75.600  94.259  wanted to hear and you listen and many of you ...

# %% [markdown]
# # Short Selected word

# %%
selected_word = pd.read_csv('slected_word.csv')
selected_word.drop(columns='Unnamed: 0', inplace=True)
selected_word.head()
# Out:
#          Word  Frequency
# 0      people         37
# 1    property         34
# 2      market         23
# 3         one         22
# 4  properties         20

# %% [markdown]
# # Weighted Selection

# %%
import pandas as pd
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords

df = combined_df

# Load NLTK stopwords
stop_words = set(stopwords.words("english"))

# Create the engaging words DataFrame
engaging_words_df = selected_word

# Function to preprocess the text and tokenize it
def preprocess_text(text):
    words = word_tokenize(text.lower())
    words = [word for word in words if word.isalnum() and word not in stop_words]
    return words

# Preprocess the text in the DataFrame
df["ProcessedText"] = df["Text"].apply(preprocess_text)

# Calculate word frequency across the entire transcript with weights for engaging words
word_frequency = {}
for _, row in df.iterrows():
    for word in row["ProcessedText"]:
        weight = engaging_words_df[engaging_words_df["Word"] == word]["Frequency"].values
        weight = weight[0] if len(weight) > 0 else 1  # Use 1 if word not found in engaging words DataFrame
        word_frequency[word] = word_frequency.get(word, 0) + weight

# Function to get the frequency score for a sentence
def get_sentence_frequency_score(sentence):
    words = preprocess_text(sentence)
    score = sum(word_frequency.get(word, 0) for word in words)
    return score

# Rank sentences based on frequency score
df["FrequencyScore"] = df["Text"].apply(get_sentence_frequency_score)

# Set the number of sentences you want in the summary
num_sentences = 10

# Extract the top sentences to form the summary
summary_sentences = df.nlargest(num_sentences, "FrequencyScore")["Text"].values

# %%
summary_sentences
# Out:
# array(["are best for you okay tell me more about FHA Loans now a couple things that I'd like to note a lot of people say go buy a home every year FHA loan FHA loan rinse and repeat right that's not impossible but there's some obstacles to overcome number one you can only have one FHA loan at a time so these are going to be kind of some myths around the FHA one you can only have one at a",
#        "FHA loan so in most cases when someone comes to us with the one brokerage and says I want to buy a primary residence I want a house act what can I do we start with the FHA low if you don't already have one that's usually what we do and if you do have one then we say well here's a conventional option or do you want to refinance out of the FHA and use that to buy so Christian what advice do",
#        "all the same so what are the issues people are having right now is what I refer to as the golden handcuffs dilemma you bought a property with an FHA loan you have a killer interest rate 3.25 3.75 rates are going to be for uh primary residence probably closer to seven maybe High sixes right now you don't want to refi out of your FHA loan because you're going to get a worse rate",
#        "that doesn't make the move impossible you have to make enough money to qualify for both mortgages at the same time if you don't move 100 miles away which most people aren't unless they get redeployed for work or you know repositioned or something or maybe they're moving family or going off to school or something so that's a big one that people a lot of times Overlook because they think I'm",
#        "that's just a single bank that offers a single luck right go somewhere that knows different products that can help you pick the one that's right for you and can help you get in the property where you otherwise wouldn't be able to otherwise right Christian thank you so much for your time and sharing your knowledge regarding FHA Loans I feel smarter I'm sure a lot of our audience",
#        "flow you know everybody can focus on one specific property inside cash flow but what if we refinanced and and lost a thousand dollars of cash flow from this property but we gained 1200 on another one like that's still a 200 gain and if losing the Thousand opened up the opportunity to get the 1200 that's still a win at the end of the day right because then you can still go refinance",
#        "just gonna buy one house a year and I'm gonna buy up my whole block and that gets very difficult to qualify for when you can't use the rental income from the houses you're vacating every year number two probably the the most misunderstood Rule and then the least well-known one is the self-sufficiency rule this really hit us in California when you're buying a three and four unit property that's it",
#        "absolutely right that's that's a Rob answer right there but yeah that's you know when you get lower than 600 though I don't want to say hey you got a 502 credit score FHA loan is going to be a slam dunk just because something's possible doesn't mean it's going to be easy because it could still be more expensive loan with the lower rates right or the lower credit score yeah and",
#        "you have for people that are going to approach their loan officer with this Vegas is that if you're not hearing this advice probably talking to the wrong guy you need to talk to somebody who's knowledgeable bread products don't talk to a loan officer that just offers one product it's the biggest mistake people make I go to Chase and I get a Chase loan okay that's not shade at Chase",
#        "three or a four unit property assuming it meets the self-sufficiency rule which we talked about that's different than conventional loads right when you're buying a three or four unit property with a conventional loan what's the minimum down payment three or fours are going to be 22 unit is going to be 15. there we go and fhas you could still use three and a half percent down to buy"],
#       dtype=object)

# %% [markdown]
# # Processed selected word

# %%
result = pd.DataFrame()
for sentence in summary_sentences:
    rows = df[df['Text'] == sentence]
    result = result.append(rows)
    
result
# Out:
# C:\Users\drago\AppData\Local\Temp\ipykernel_2284\2149340864.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(rows)
# C:\Users\drago\AppData\Local\Temp\ipykernel_2284\2149340864.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(rows)
# C:\Users\drago\AppData\Local\Temp\ipykernel_2284\2149340864.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(rows)
# C:\Users\drago\AppData\Local\Temp\ipykernel_2284\2149340864.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(rows)
# C:\Users\drago\AppData\Local\Temp\ipykernel_2284\2149340864.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(rows)
# C:\Users\drago\AppData\Local\Temp\ipykernel_2284\2149340864.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(rows)
# C:\Users\drago\AppData\Local\Temp\ipykernel_2284\2149340864.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(rows)
# C:\Users\drago\AppData\Local\Temp\ipykernel_2284\2149340864.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(rows)
# C:\Users\drago\AppData\Local\Temp\ipykernel_2284\2149340864.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(rows)
# C:\Users\drago\AppData\Local\Temp\ipykernel_2284\2149340864.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(rows)
#       Start      End                                               Text  \
# 17  299.699  320.520  are best for you okay tell me more about FHA L...
# 45  814.380  833.100  FHA loan so in most cases when someone comes t...
# 31  559.260  582.360  all the same so what are the issues people are...
# 21  376.680  394.020  that doesn't make the move impossible you have...
# 47  846.959  863.880  that's just a single bank that offers a single...
# 36  650.640  669.839  flow you know everybody can focus on one speci...
# 22  392.940  412.680  just gonna buy one house a year and I'm gonna ...
# 13  232.260  250.500  absolutely right that's that's a Rob answer ri...
# 46  832.079  848.639  you have for people that are going to approach...
# 29  523.979  544.200  three or a four unit property assuming it meet...
#
#                                         ProcessedText  FrequencyScore
# 17  [best, okay, tell, fha, loans, couple, things,...            5253
# 45  [fha, loan, cases, someone, comes, us, one, br...            3950
# 31  [issues, people, right, refer, golden, handcuf...            3307
# 21  [make, move, impossible, make, enough, money, ...            3110
# 47  [single, bank, offers, single, luck, right, go...            3092
# 36  [flow, know, everybody, focus, one, specific, ...            3088
# 22  [gon, na, buy, one, house, year, gon, na, buy,...            2919
# 13  [absolutely, right, rob, answer, right, yeah, ...            2791
# 46  [people, going, approach, loan, officer, vegas...            2764
# 29  [three, four, unit, property, assuming, meets,...            2723

# %%
import pandas as pd

def filter_transcript_by_range(original_df, selected_df):
    filtered_rows = []
    for _, row in selected_df.iterrows():
        start_time = row['Start']
        # Calculate the range based on the midpoint of selected_df start
        lower_bound = start_time - 30
        upper_bound = start_time + 30
        
        # Filter rows based on the range
        filtered_rows.extend(original_df[(original_df['Start'] >= lower_bound) & 
                                         (original_df['Start'] <= upper_bound)].values.tolist())

    # Create a new DataFrame from the filtered rows
    filtered_df = pd.DataFrame(filtered_rows, columns=original_df.columns)

    return filtered_df

# Example usage
# Assuming your original DataFrame is called 'youtube_df' and the selected DataFrame is 'selected_df'
new_dataset = filter_transcript_by_range(combined_df, result)

# %%
new_dataset
# Out:
#       Start      End                                               Text  \
# 0   283.620  301.440  whereas FHA we've got them through as high as ...
# 1   299.699  320.520  are best for you okay tell me more about FHA L...
# 2   318.720  339.900  time that does not mean you can only have one ...
# 3   795.779  816.600  it's going to be tough to use an FHA loan to g...
# 4   814.380  833.100  FHA loan so in most cases when someone comes t...
# 5   832.079  848.639  you have for people that are going to approach...
# 6   542.399  560.459  these properties correct that's the massive ad...
# 7   559.260  582.360  all the same so what are the issues people are...
# 8   580.200  599.519  but you can't use the FHA loan to buy future p...
# 9   358.080  378.360  your old house into a rent this is getting int...
# 10  376.680  394.020  that doesn't make the move impossible you have...
# 11  392.940  412.680  just gonna buy one house a year and I'm gonna ...
# 12  832.079  848.639  you have for people that are going to approach...
# 13  846.959  863.880  that's just a single bank that offers a single...
# 14  862.079  882.600  does as well where can people reach out to fin...
# 15  633.779  652.380  would ever be financially advantageous to refi...
# 16  650.640  669.839  flow you know everybody can focus on one speci...
# 17  667.860  685.440  both of them later and drop it back so I I mea...
# 18  376.680  394.020  that doesn't make the move impossible you have...
# 19  392.940  412.680  just gonna buy one house a year and I'm gonna ...
# 20  411.300  432.600  this doesn't account for a single family or du...
# 21  215.220  233.580  significant it's probably a much wider margin ...
# 22  232.260  250.500  absolutely right that's that's a Rob answer ri...
# 23  249.120  266.759  there's underwriting criteria that you're goin...
# 24  814.380  833.100  FHA loan so in most cases when someone comes t...
# 25  832.079  848.639  you have for people that are going to approach...
# 26  846.959  863.880  that's just a single bank that offers a single...
# 27  862.079  882.600  does as well where can people reach out to fin...
# 28  507.180  525.959  telling people to do for the whole time we've ...
# 29  523.979  544.200  three or a four unit property assuming it meet...
# 30  542.399  560.459  these properties correct that's the massive ad...
#
#                                         ProcessedText  FrequencyScore
# 0   [whereas, fha, got, high, 57, half, grossing, ...             959
# 1   [best, okay, tell, fha, loans, couple, things,...            5253
# 2   [time, mean, one, ever, okay, buy, refinance, ...            2169
# 3   [going, tough, use, fha, loan, get, triplex, f...             951
# 4   [fha, loan, cases, someone, comes, us, one, br...            3950
# 5   [people, going, approach, loan, officer, vegas...            2764
# 6   [properties, correct, massive, advantage, fha,...            1263
# 7   [issues, people, right, refer, golden, handcuf...            3307
# 8   [ca, use, fha, loan, buy, future, properties, ...            1279
# 9   [old, house, rent, getting, weeds, little, bit...            1160
# 10  [make, move, impossible, make, enough, money, ...            3110
# 11  [gon, na, buy, one, house, year, gon, na, buy,...            2919
# 12  [people, going, approach, loan, officer, vegas...            2764
# 13  [single, bank, offers, single, luck, right, go...            3092
# 14  [well, people, reach, find, connect, yep, anyw...            2228
# 15  [would, ever, financially, advantageous, refin...             883
# 16  [flow, know, everybody, focus, one, specific, ...            3088
# 17  [later, drop, back, mean, answer, would, yes, ...             470
# 18  [make, move, impossible, make, enough, money, ...            3110
# 19  [gon, na, buy, one, house, year, gon, na, buy,...            2919
# 20  [account, single, family, duplex, buying, thre...            1762
# 21  [significant, probably, much, wider, margin, p...            2132
# 22  [absolutely, right, rob, answer, right, yeah, ...            2791
# 23  [underwriting, criteria, going, hurdle, yes, a...            1735
# 24  [fha, loan, cases, someone, comes, us, one, br...            3950
# 25  [people, going, approach, loan, officer, vegas...            2764
# 26  [single, bank, offers, single, luck, right, go...            3092
# 27  [well, people, reach, find, connect, yep, anyw...            2228
# 28  [telling, people, whole, time, bus, yeah, kind...            2466
# 29  [three, four, unit, property, assuming, meets,...            2723
# 30  [properties, correct, massive, advantage, fha,...            1263

# %%
# Put them together
df = new_dataset

# Combine rows in groups of 10
combined_rows = []
group_size = 3
num_groups = (len(df) + group_size - 1) // group_size  # Calculate the number of groups

for i in range(num_groups):
    start_idx = i * group_size
    end_idx = min(start_idx + group_size, len(df)) - 1  # Handle last group with fewer than 10 rows
    start_text = df.loc[start_idx, 'Text']
    end_text = df.loc[end_idx, 'Text']
    combined_text = ' '.join(df.loc[start_idx:end_idx, 'Text'])
    combined_rows.append({'Start': df.loc[start_idx, 'Start'], 'End': df.loc[end_idx, 'End'], 'Text': combined_text})

# Create a new DataFrame with combined rows
combined_df = pd.DataFrame(combined_rows)

combined_df
# Out:
#       Start      End                                               Text
# 0   283.620  339.900  whereas FHA we've got them through as high as ...
# 1   795.779  848.639  it's going to be tough to use an FHA loan to g...
# 2   542.399  599.519  these properties correct that's the massive ad...
# 3   358.080  412.680  your old house into a rent this is getting int...
# 4   832.079  882.600  you have for people that are going to approach...
# 5   633.779  685.440  would ever be financially advantageous to refi...
# 6   376.680  432.600  that doesn't make the move impossible you have...
# 7   215.220  266.759  significant it's probably a much wider margin ...
# 8   814.380  863.880  FHA loan so in most cases when someone comes t...
# 9   862.079  544.200  does as well where can people reach out to fin...
# 10  542.399  560.459  these properties correct that's the massive ad...

# %%
# FInsihed
combined_df.to_csv('result4-2_2.csv')

# %% [markdown]
# # Combined anpther version

# %%
import pandas as pd

def filter_transcript_by_range(original_df, selected_df):
    grouped_text = {}
    
    for _, row in selected_df.iterrows():
        start_time = row['Start']
        # Calculate the range based on the midpoint of selected_df start
        lower_bound = start_time - 30
        upper_bound = start_time + 30
        
        # Filter rows based on the range
        filtered_rows = original_df[(original_df['Start'] >= lower_bound) & 
                                    (original_df['Start'] <= upper_bound)]
        
        # Combine the text from filtered rows
        combined_text = ' '.join(filtered_rows['Text'])
        
        # Store the combined text in the grouped_text dictionary
        if combined_text:
            if start_time not in grouped_text:
                grouped_text[start_time] = []
            grouped_text[start_time].append(combined_text)

    # Convert the grouped_text dictionary into a DataFrame
    grouped_df = pd.DataFrame({'Start': list(grouped_text.keys()), 'CombinedText': list(grouped_text.values())})

    return grouped_df

# Example usage
# Assuming your original DataFrame is called 'youtube_df' and the selected DataFrame is 'selected_df'
new_dataset = filter_transcript_by_range(combined_df, result)

# %%
new_dataset
# Out:
#      Start                                       CombinedText
# 0  299.699  [whereas FHA we've got them through as high as...
# 1  814.380  [it's going to be tough to use an FHA loan to ...
# 2  559.260  [these properties correct that's the massive a...
# 3  376.680  [your old house into a rent this is getting in...
# 4  846.959  [you have for people that are going to approac...
# 5  650.640  [would ever be financially advantageous to ref...
# 6  392.940  [that doesn't make the move impossible you hav...
# 7  232.260  [significant it's probably a much wider margin...
# 8  832.079  [FHA loan so in most cases when someone comes ...
# 9  523.979  [telling people to do for the whole time we've...

# %%
new_dataset.to_csv('result4-2_1.csv')

# %%
# Out:
#                                                Start      End  \
# 0  16    283.620
# 17    299.699
# 18    318.720
# Name...  320.520
# 1  44    795.779
# 45    814.380
# 46    832.079
# Name...  833.100
# 2  30    542.399
# 31    559.260
# 32    580.200
# Name...  582.360
# 3  20    358.08
# 21    376.68
# 22    392.94
# Name: S...  394.020
# 4  46    832.079
# 47    846.959
# 48    862.079
# Name...  863.880
# 5  35    633.779
# 36    650.640
# 37    667.860
# Name...  669.839
# 6  21    376.68
# 22    392.94
# 23    411.30
# Name: S...  412.680
# 7  12    215.22
# 13    232.26
# 14    249.12
# Name: S...  250.500
# 8  45    814.380
# 46    832.079
# 47    846.959
# 48  ...  848.639
# 9  28    507.180
# 29    523.979
# 30    542.399
# Name...  544.200
#
#                                         CombinedText
# 0  whereas FHA we've got them through as high as ...
# 1  it's going to be tough to use an FHA loan to g...
# 2  these properties correct that's the massive ad...
# 3  your old house into a rent this is getting int...
# 4  you have for people that are going to approach...
# 5  would ever be financially advantageous to refi...
# 6  that doesn't make the move impossible you have...
# 7  significant it's probably a much wider margin ...
# 8  FHA loan so in most cases when someone comes t...
# 9  telling people to do for the whole time we've ...

# %%
# Out:
#      Start      End                                       CombinedText
# 0  299.699  320.520  are best for you okay tell me more about FHA L...
# 1  814.380  833.100  FHA loan so in most cases when someone comes t...
# 2  559.260  582.360  all the same so what are the issues people are...
# 3  376.680  394.020  that doesn't make the move impossible you have...
# 4  846.959  863.880  that's just a single bank that offers a single...
# 5  650.640  669.839  flow you know everybody can focus on one speci...
# 6  392.940  412.680  just gonna buy one house a year and I'm gonna ...
# 7  232.260  250.500  absolutely right that's that's a Rob answer ri...
# 8  832.079  848.639  you have for people that are going to approach...
# 9  523.979  544.200  three or a four unit property assuming it meet...
