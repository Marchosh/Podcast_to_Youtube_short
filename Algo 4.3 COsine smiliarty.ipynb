# %%
from youtube_transcript_api import YouTubeTranscriptApi
import pandas as pd


def get_youtube_video_transcript_dataframe(youtube_url):
    try:
        # Extract video ID from the URL
        video_id = youtube_url.split("v=")[-1]

        # Get the transcript
        transcript = YouTubeTranscriptApi.get_transcript(video_id)

        # Create an empty list to store the transcript data
        transcript_data = []

        # Loop through each transcript item and extract timestamp and text
        for item in transcript:
            start_time = item["start"]
            end_time = item["start"] + item["duration"]
            text = item["text"]
            transcript_data.append({"Start": start_time, "End": end_time, "Text": text})

        # Convert the list to a pandas DataFrame
        df = pd.DataFrame(transcript_data)

        return df

    except Exception as e:
        print("Error:", e)
        return None

# Replace the following with the YouTube video URL of your choice
youtube_url = "https://www.youtube.com/watch?v=sJwIQW4rbUM&ab_channel=BiggerPockets"
transcript_df = get_youtube_video_transcript_dataframe(youtube_url)

if transcript_df is not None:
    print(transcript_df.head())
else:
    print("Failed to get the transcript.")
# Out:
#    Start     End                                     Text
# 0  0.000   3.959   how many bits do you believe about the
# 1  2.639   4.980      mortgage industry is there a chance
# 2  3.959   6.600     you've been running around with that
# 3  4.980   8.280  info in your head that if you got right
# 4  6.600  10.019   could actually make you a lot of money

# %% [markdown]
# # Preprocessed

# %%
df = transcript_df

# Combine rows in groups of 10
combined_rows = []
group_size = 10
num_groups = (len(df) + group_size - 1) // group_size  # Calculate the number of groups

for i in range(num_groups):
    start_idx = i * group_size
    end_idx = min(start_idx + group_size, len(df)) - 1  # Handle last group with fewer than 10 rows
    start_text = df.loc[start_idx, 'Text']
    end_text = df.loc[end_idx, 'Text']
    combined_text = ' '.join(df.loc[start_idx:end_idx, 'Text'])
    combined_rows.append({'Start': df.loc[start_idx, 'Start'], 'End': df.loc[end_idx, 'End'], 'Text': combined_text})

# Create a new DataFrame with combined rows
combined_df = pd.DataFrame(combined_rows)

combined_df.head()
# Out:
#     Start     End                                               Text
# 0   0.000  17.640  how many bits do you believe about the mortgag...
# 1  16.139  35.579  perfectly as we can we've come to the right pl...
# 2  33.239  53.820  coming up on today's show of mortgage Mondays ...
# 3  52.379  74.280  glad to hear it all right let's get into this ...
# 4  72.540  90.360  the Burr in most cases now is there a value to...

# %% [markdown]
# # Short Selected word

# %%
# Instead of the word it should be whole sentences of short video


shorts = pd.read_csv('Short_combinedtranscript.csv')
shorts.drop(columns='Unnamed: 0', inplace=True)
shorts.head()
# Out:
#    VideoID                                       CombinedText
# 0        0  so a winning bur is anytime you get more of yo...
# 1        1  I think one of the problems that people have a...
# 2        2  I think that the reason most people don't scal...
# 3        3  what's your advice for people who are chasing ...
# 4        4  everybody focuses on buying Equity buying Equi...

# %% [markdown]
# # Cosine SImilarity Selection V1

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Load the datasets
video_transcript_df = combined_df
short_video_transcript_df = shorts

# Create a TF-IDF vectorizer
vectorizer = TfidfVectorizer(stop_words='english')

# Vectorize the video transcript and short video transcript text
video_transcript_vectors = vectorizer.fit_transform(video_transcript_df['Text'])
short_video_transcript_vectors = vectorizer.transform(short_video_transcript_df['CombinedText'])

# Calculate cosine similarity between short video transcript and video transcript
cosine_similarities = cosine_similarity(short_video_transcript_vectors, video_transcript_vectors)

# Find the indices and values of most similar rows in video transcript for each short video transcript
most_similar_indices = np.argmax(cosine_similarities, axis=1)
max_similarity_values = np.max(cosine_similarities, axis=1)

# Create a DataFrame to store the results
result_df = pd.DataFrame(columns=['VideoID', 'CombinedText', 'Start', 'End', 'Text', 'SimilarityScore'])

# Populate the result DataFrame with most similar rows from video transcript
for short_idx, video_idx in enumerate(most_similar_indices):
    result_df = result_df.append({
        'VideoID': short_idx,
        'CombinedText': short_video_transcript_df.loc[short_idx, 'CombinedText'],
        'Start': video_transcript_df.loc[video_idx, 'Start'],
        'End': video_transcript_df.loc[video_idx, 'End'],
        'Text': video_transcript_df.loc[video_idx, 'Text'],
        'SimilarityScore': max_similarity_values[short_idx]
    }, ignore_index=True)

# Sort the result DataFrame by similarity score in descending order
result_df = result_df.sort_values(by='SimilarityScore', ascending=False)

# Reset the index of the sorted DataFrame
result_df = result_df.reset_index(drop=True)

# Display the result DataFrame
result_df
# Out:
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
# C:\Users\drago\AppData\Local\Temp\ipykernel_8080\896177546.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({
#    VideoID                                       CombinedText    Start  \
# 0        2  I think that the reason most people don't scal...  450.000
# 1       17  tell us about the nature of the housing market...  597.899
# 2       40  you know how sometimes you'll be trying really...  215.220
# 3        3  what's your advice for people who are chasing ...    0.000
# 4       18  this is an unpopular opinion people get mad at...  916.680
# 5       10  how do you optimize that part of the process t...  318.720
# 6       13  what's the first thing you do whenever you're ...    0.000
# 7        5  we all learn as Real Estate Investors every si...  814.380
# 8       39  don't just think the llc's or magic pill is go...  814.380
# 9       36  what are your thoughts on selling our primary ...  110.759
# 10      41  I'm cash flowing literally 5K a month from one...  650.640
# 11      27  when you own real estate yourself you develop ...  215.220
# 12      19  you can't be so laser focused on one strategy ...  283.620
# 13      14  we have created so much inflation that you can...  667.860
# 14      33  one thing I'll never get bored of French peopl...  650.640
# 15      35  my husband and I have two long-term Investment...  450.000
# 16       9  are there other tactics to get a better price ...  376.680
# 17      38  do you feel like there's a sweet spot in terms...  450.000
# 18      26  when do you know when to throw in the towel on...  376.680
# 19       4  everybody focuses on buying Equity buying Equi...  392.940
# 20      34  people are eager to buy into the housing marke...  181.739
# 21      22  what's funny is that the highest bracket usual...  814.380
# 22      30  as someone who's been very successful with rea...  667.860
# 23      23  what are some things that people should know a...  916.680
# 24       1  I think one of the problems that people have a...  215.220
# 25      12  just give you guys a quick story Gala Winery t...   75.600
# 26      16  if you get told that life is supposed to be ea...  376.680
# 27       7  I literally just saw what life could be like i...  283.620
# 28       6  everything you do has a dollar per hour attach...   54.059
# 29      21  you first start learning about real estate we ...  650.640
# 30      24  so guys let's talk about the market man things...  542.399
# 31      32  three years ago I was working 60 hours a week ...  580.200
# 32      25  going to cover how to find and finance Investm...  215.220
# 33      11  I'm going to try to talk to people that are br...  376.680
# 34      28  have a wacky formula for buying real estate an...  650.640
# 35       8  having multiple income streams protects you as...  249.120
# 36      31  come here so you know that feeling when you're...  430.080
# 37      20  the Florida housing market has been on fire in...  392.940
# 38      29  refinance 3.0 so that's what happens when you ...  542.399
# 39       0  so a winning bur is anytime you get more of yo...  559.260
# 40      37  12 haircuts allowed me to buy my first rental ...  392.940
# 41      15  today we are going to be talking about one of ...    0.000
#
#         End                                               Text  \
# 0   468.539  conventional loan or just put more money down ...
# 1   617.459  it's a one and a half percent down payment dif...
# 2   233.580  significant it's probably a much wider margin ...
# 3    19.260  welcome to mortgage Mondays Today's Show we ar...
# 4   944.480  money with real estate if you've got some time...
# 5   339.900  time that does not mean you can only have one ...
# 6    19.260  welcome to mortgage Mondays Today's Show we ar...
# 7   833.100  FHA loan so in most cases when someone comes t...
# 8   833.100  FHA loan so in most cases when someone comes t...
# 9   130.739  only loan so that means you have to live there...
# 10  669.839  flow you know everybody can focus on one speci...
# 11  233.580  significant it's probably a much wider margin ...
# 12  301.440  whereas FHA we've got them through as high as ...
# 13  685.440  both of them later and drop it back so I I mea...
# 14  669.839  flow you know everybody can focus on one speci...
# 15  468.539  conventional loan or just put more money down ...
# 16  394.020  that doesn't make the move impossible you have...
# 17  468.539  conventional loan or just put more money down ...
# 18  394.020  that doesn't make the move impossible you have...
# 19  412.680  just gonna buy one house a year and I'm gonna ...
# 20  200.040  you mentioned FHA stands for the federal housi...
# 21  833.100  FHA loan so in most cases when someone comes t...
# 22  685.440  both of them later and drop it back so I I mea...
# 23  944.480  money with real estate if you've got some time...
# 24  233.580  significant it's probably a much wider margin ...
# 25   94.259  wanted to hear and you listen and many of you ...
# 26  394.020  that doesn't make the move impossible you have...
# 27  301.440  whereas FHA we've got them through as high as ...
# 28   77.400  like BiggerPockets welcome to mortgage Mondays...
# 29  669.839  flow you know everybody can focus on one speci...
# 30  560.459  these properties correct that's the massive ad...
# 31  599.519  but you can't use the FHA loan to buy future p...
# 32  233.580  significant it's probably a much wider margin ...
# 33  394.020  that doesn't make the move impossible you have...
# 34  669.839  flow you know everybody can focus on one speci...
# 35  266.759  there's underwriting criteria that you're goin...
# 36  451.800  with 75 has to be more than your mortgage and ...
# 37  412.680  just gonna buy one house a year and I'm gonna ...
# 38  560.459  these properties correct that's the massive ad...
# 39  582.360  all the same so what are the issues people are...
# 40  412.680  just gonna buy one house a year and I'm gonna ...
# 41   19.260  welcome to mortgage Mondays Today's Show we ar...
#
#     SimilarityScore
# 0          0.448474
# 1          0.303672
# 2          0.301923
# 3          0.296844
# 4          0.288358
# 5          0.286322
# 6          0.278878
# 7          0.274576
# 8          0.265357
# 9          0.262191
# 10         0.257061
# 11         0.251624
# 12         0.245066
# 13         0.242608
# 14         0.241917
# 15         0.238414
# 16         0.234433
# 17         0.229060
# 18         0.223633
# 19         0.223400
# 20         0.220093
# 21         0.217609
# 22         0.213300
# 23         0.212546
# 24         0.211933
# 25         0.209952
# 26         0.194869
# 27         0.194044
# 28         0.186762
# 29         0.170843
# 30         0.169153
# 31         0.165037
# 32         0.164766
# 33         0.164734
# 34         0.160430
# 35         0.158831
# 36         0.158193
# 37         0.148789
# 38         0.144939
# 39         0.144019
# 40         0.140295
# 41         0.112164

# %% [markdown]
# # Cosine Similarity V2 (combined all the shorts into 1 rows)

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Load the datasets
video_transcript_df = combined_df
short_video_transcript_df = shorts

# Combine the short video transcript rows into a single text
short_combined_text = ' '.join(short_video_transcript_df['CombinedText'])

# Create a TF-IDF vectorizer
vectorizer = TfidfVectorizer(stop_words='english')

# Vectorize the video transcript and short combined transcript text
video_transcript_vectors = vectorizer.fit_transform(video_transcript_df['Text'])
short_combined_vector = vectorizer.transform([short_combined_text])

# Calculate cosine similarity for each row in video transcript against the combined short transcript
cosine_similarities = cosine_similarity(video_transcript_vectors, short_combined_vector)

# Add the similarity scores to the video transcript DataFrame
video_transcript_df['SimilarityScore'] = cosine_similarities

# Sort the video transcript DataFrame by similarity score in descending order
result_df = video_transcript_df.sort_values(by='SimilarityScore', ascending=False)

# Reset the index of the sorted DataFrame
result_df = result_df.reset_index(drop=True)

# Display the result DataFrame
result_df
# Out:
#       Start      End                                               Text  \
# 0   597.839  618.000  offer it it's more difficult cold than a norma...
# 1   756.120  774.959  appreciate you helping me dispel some of these...
# 2    52.379   74.280  glad to hear it all right let's get into this ...
# 3   616.320  634.980  them on Zillow are the hardest to put in a con...
# 4   454.560  473.819  someone did I would say this is a stupid way t...
# 5   385.380  404.460  good for me right don't just go pull your cred...
# 6    72.540   90.360  the Burr in most cases now is there a value to...
# 7   126.960  146.160  payment and the Renault or if you're just refi...
# 8   632.940  652.320  been sitting on the market for 250 days but th...
# 9   348.780  367.860  can get multiple credit pulls and it will only...
# 10  106.500  128.580  just buy a primary residence every year if pos...
# 11  722.700  741.240  refinance right you you piecemeal it like you ...
# 12  544.200  562.560  conventional one and there's a hard money one ...
# 13    0.000   17.640  how many bits do you believe about the mortgag...
# 14  650.459  670.500  term they're incredibly difficult to use to ge...
# 15  291.600  312.060  experience being a broker getting approved in ...
# 16   88.740  109.020  ideally you want the juice to be worth the squ...
# 17  739.019  758.100  you know so typically historically speaking th...
# 18  366.840  387.180  credit long term because you're building up in...
# 19  704.640  724.500  property working or being able to Front The Up...
# 20  686.279  706.560  easier versus trying to use one load product f...
# 21  164.340  184.019  deal and if you get more than your money out s...
# 22   16.139   35.579  perfectly as we can we've come to the right pl...
# 23  668.880  688.079  load that makes it easier to get into a proper...
# 24  580.140  600.120  of after the property is renovated and you can...
# 25  198.720  222.000  money out normally you'd had to put 20 down or...
# 26  310.440  332.400  years still have good credit at a certain poin...
# 27  506.099  525.660  you got to learn how to play this game if you ...
# 28  419.340  438.840  like they know their stuff if you read it what...
# 29  471.840  491.220  understand why they do that but they do I also...
# 30  182.280  200.340  you just bought it traditionally so in other w...
# 31  274.860  293.280  717 for the next four years absolutely not tha...
# 32  523.979  545.580  take these two couples and have them sleeping ...
# 33  773.160  790.440  for mortgages people are trying to get you in ...
# 34   33.239   53.820  coming up on today's show of mortgage Mondays ...
# 35  402.240  420.780  often has no idea how loan stuff goes they bar...
# 36  436.620  456.539  to a horrible financial crisis where I believe...
# 37  237.900  257.699  you're basically setting yourself back one mon...
# 38  219.959  239.280  credit score Christian what say you about this...
# 39  788.399  808.680  theonbrokerge.com and that's also our website ...
# 40  330.539  350.280  shouldn't come to another broker to do the sam...
# 41  144.360  165.780  Grand Slam but no I would definitely not class...
# 42  561.120  582.000  and refinance and do a better product the one ...
# 43  254.580  277.560  rate so dropping from a 720 to a 717 is not go...
# 44  489.300  507.300  payments on time there's a lot of things that ...
# 45  807.420  826.910  you with because we care about your financial ...
# 46  824.760  847.880  already see you on the next one [Music] [Music...
#
#     SimilarityScore
# 0          0.273250
# 1          0.263108
# 2          0.259854
# 3          0.251078
# 4          0.248314
# 5          0.247323
# 6          0.247315
# 7          0.241056
# 8          0.225071
# 9          0.208119
# 10         0.207552
# 11         0.201269
# 12         0.197272
# 13         0.189999
# 14         0.189567
# 15         0.185049
# 16         0.181720
# 17         0.177781
# 18         0.175176
# 19         0.173518
# 20         0.173231
# 21         0.170293
# 22         0.166445
# 23         0.164276
# 24         0.161036
# 25         0.154937
# 26         0.140029
# 27         0.139743
# 28         0.139623
# 29         0.137449
# 30         0.136778
# 31         0.130290
# 32         0.121634
# 33         0.114324
# 34         0.114091
# 35         0.109785
# 36         0.105118
# 37         0.103680
# 38         0.102110
# 39         0.097669
# 40         0.092744
# 41         0.087923
# 42         0.081949
# 43         0.077046
# 44         0.069220
# 45         0.030137
# 46         0.000000

# %%
result_df.to_csv('Algo4-3_result.csv')

# %% [markdown]
# # Cosine similairty V3 (using Word embedding instead of TF/IDF)

# %%
# !pip install spacy
# !python -m spacy download en_core_web_md
# Out:
# Requirement already satisfied: spacy in c:\users\drago\anaconda3\lib\site-packages (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\drago\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\drago\anaconda3\lib\site-packages (from spacy) (3.0.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\drago\anaconda3\lib\site-packages (from spacy) (2.0.9)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\drago\anaconda3\lib\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\drago\anaconda3\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\drago\anaconda3\lib\site-packages (from spacy) (22.0)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\drago\anaconda3\lib\site-packages (from spacy) (1.23.5)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\drago\anaconda3\lib\site-packages (from spacy) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\drago\anaconda3\lib\site-packages (from spacy) (4.64.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\drago\anaconda3\lib\site-packages (from spacy) (2.28.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in c:\users\drago\anaconda3\lib\site-packages (from spacy) (8.1.11)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\drago\anaconda3\lib\site-packages (from spacy) (2.0.7)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\drago\anaconda3\lib\site-packages (from spacy) (1.0.4)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\drago\anaconda3\lib\site-packages (from spacy) (2.4.7)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\drago\anaconda3\lib\site-packages (from spacy) (0.10.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\drago\anaconda3\lib\site-packages (from spacy) (1.0.9)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\drago\anaconda3\lib\site-packages (from spacy) (2.1.1)
# Requirement already satisfied: jinja2 in c:\users\drago\anaconda3\lib\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\drago\anaconda3\lib\site-packages (from spacy) (65.6.3)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\drago\anaconda3\lib\site-packages (from spacy) (0.9.0)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\drago\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.7.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\drago\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.5.0)
# Requirement already satisfied: pydantic-core==2.4.0 in c:\users\drago\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\drago\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\drago\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\drago\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\drago\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.14)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\drago\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.1.1)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\drago\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.10)
# Requirement already satisfied: colorama in c:\users\drago\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\drago\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\drago\anaconda3\lib\site-packages (from jinja2->spacy) (2.1.1)
# Collecting en-core-web-md==3.6.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.6.0/en_core_web_md-3.6.0-py3-none-any.whl (42.8 MB)
#      ---------------------------------------- 42.8/42.8 MB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in c:\users\drago\anaconda3\lib\site-packages (from en-core-web-md==3.6.0) (3.6.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\drago\anaconda3\lib\site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (5.2.1)
# Requirement already satisfied: jinja2 in c:\users\drago\anaconda3\lib\site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (3.1.2)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\drago\anaconda3\lib\site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\drago\anaconda3\lib\site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (22.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\drago\anaconda3\lib\site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.28.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\drago\anaconda3\lib\site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (1.0.4)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\drago\anaconda3\lib\site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (3.3.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\drago\anaconda3\lib\site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (3.0.12)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\drago\anaconda3\lib\site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (0.10.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\drago\anaconda3\lib\site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.1.1)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\drago\anaconda3\lib\site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (0.9.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\drago\anaconda3\lib\site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.4.7)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\drago\anaconda3\lib\site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (4.64.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\drago\anaconda3\lib\site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (1.0.9)
# Requirement already satisfied: setuptools in c:\users\drago\anaconda3\lib\site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (65.6.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\drago\anaconda3\lib\site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\drago\anaconda3\lib\site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in c:\users\drago\anaconda3\lib\site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (8.1.11)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\drago\anaconda3\lib\site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.0.9)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\drago\anaconda3\lib\site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (1.1.2)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\drago\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (0.5.0)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\drago\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (4.7.1)
# Requirement already satisfied: pydantic-core==2.4.0 in c:\users\drago\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\drago\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\drago\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\drago\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\drago\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (3.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\drago\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\drago\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (0.1.1)
# Requirement already satisfied: colorama in c:\users\drago\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\drago\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\drago\anaconda3\lib\site-packages (from jinja2->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.1.1)
# Installing collected packages: en-core-web-md
# Successfully installed en-core-web-md-3.6.0
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')

# %%
import pandas as pd
import spacy
from sklearn.metrics.pairwise import cosine_similarity

# Load the pre-trained GloVe embeddings model
nlp = spacy.load("en_core_web_md")

# Load the datasets
video_transcript_df = combined_df
short_video_transcript_df = shorts

# Combine the short video transcript rows into a single text
short_combined_text = ' '.join(short_video_transcript_df['CombinedText'])

# Calculate embeddings for the video transcript and short combined transcript text
video_transcript_embeddings = [nlp(text).vector for text in video_transcript_df['Text']]
short_combined_embedding = nlp(short_combined_text).vector

# Calculate cosine similarity for each row in video transcript against the combined short transcript
cosine_similarities = cosine_similarity(video_transcript_embeddings, [short_combined_embedding])

# Add the similarity scores to the video transcript DataFrame
video_transcript_df['SimilarityScore'] = cosine_similarities.T

# Sort the video transcript DataFrame by similarity score in descending order
result_df = video_transcript_df.sort_values(by='SimilarityScore', ascending=False)

# Reset the index of the sorted DataFrame
result_df = result_df.reset_index(drop=True)

# Display the result DataFrame
result_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 23
#      20 cosine_similarities = cosine_similarity(video_transcript_embeddings, [short_combined_embedding])
#      22 # Add the similarity scores to the video transcript DataFrame
# ---> 23 video_transcript_df['SimilarityScore'] = cosine_similarities.T
#      25 # Sort the video transcript DataFrame by similarity score in descending order
#      26 result_df = video_transcript_df.sort_values(by='SimilarityScore', ascending=False)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3980, in DataFrame.__setitem__(self, key, value)
#    3977     self._setitem_array([key], value)
#    3978 else:
#    3979     # set column
# -> 3980     self._set_item(key, value)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4174, in DataFrame._set_item(self, key, value)
#    4164 def _set_item(self, key, value) -> None:
#    4165     """
#    4166     Add series to DataFrame in specified column.
#    4167
#    (...)
#    4172     ensure homogeneity.
#    4173     """
# -> 4174     value = self._sanitize_column(value)
#    4176     if (
#    4177         key in self.columns
#    4178         and value.ndim == 1
#    4179         and not is_extension_array_dtype(value)
#    4180     ):
#    4181         # broadcast across multiple columns if necessary
#    4182         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4915, in DataFrame._sanitize_column(self, value)
#    4912     return _reindex_for_setitem(Series(value), self.index)
#    4914 if is_list_like(value):
# -> 4915     com.require_length_match(value, self.index)
#    4916 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File ~\anaconda3\lib\site-packages\pandas\core\common.py:571, in require_length_match(data, index)
#     567 """
#     568 Check the length of data matches the length of the index.
#     569 """
#     570 if len(data) != len(index):
# --> 571     raise ValueError(
#     572         "Length of values "
#     573         f"({len(data)}) "
#     574         "does not match length of index "
#     575         f"({len(index)})"
#     576     )
#
# ValueError: Length of values (1) does not match length of index (52)
